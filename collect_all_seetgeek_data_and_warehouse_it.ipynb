# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine # database connection
import sqlite3
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# # Create database
#
# This step should only be execute the first time. After the database has been created the first time, then creating a database is deprecated. If we create the database again we will acidentially lose of the the prior data we have collected.

# %%
# create a database that will hold all ticket touting information
# e.g. table for artist_ids and information, 
# table for concerts affiliated for a particular genre, etc.

# Initializes database with filename 311_8M.db in current directory

### THIS IS THE LINE TO RUN TO CREATE THE DATABASE:
###disk_engine = create_engine('sqlite:///ticket_touting.db')

# %% [markdown]
# # Create a function!
#
# This function collects all artist information based on their genre. It then creates a column to specifiy wich genre they are, and then saves all artists into a single database.

# %%
def get_artist_by_genre(genre, per_page=5000):
    
    """Collect all artists the your genre of choice and save dataframe
    Then use data frame to store into database as a table

    Call URL for all electronic artists
    per_page = 5000 because it is the max"""
    
    # The genre must be lowercase so let's account for that
    genre = str.lower(genre)

    
    # string together url to call api
    # client_id is the api key
    # it then mashes together the api key with the desired genre and the number of results you want
    
    client_id='NDQxMDA3NXwxNDU5MDI4MzEx'
    get_artists_url = ('https://api.seatgeek.com/2/performers?format=json&client_id='+
                       client_id+'&genres.name='+genre+'&per_page='+str(per_page))
        
    
    # use url structure to call api key
    # then return json results into dataframe.
    # I am normalizing the 'performers' section of the json
    # because the other section is just meta data info. 
    # i.e. how many artists there are and other small info that 
    # can be derived from the infomatino in performers.
    
    r = requests.get(get_artists_url)
    json_all_artists = r.json()
    df_all_artists = json_normalize(json_all_artists)
    try: 
        all_artists_ids = json_normalize(df_all_artists['performers'][0])


        # once the json have been converted to a dataframe
        # I drop a couple of features: genres and taxonomies.
        # Both of the columns cause problems when we try to store them
        # into a SQL database. Both of the columns are not needed.
        # We know the genre already, so we will make a column to replace to droped 'genres.'
        # The taxonomies data does not seem to be useful. Almost all of them return the same thing.


        all_artists_ids = all_artists_ids.drop(['genres', 'taxonomies'], 1)
        # SeetGeek has a problem generating 'hip-hop' but it works
        # if you ping the api with hip or hop. Therefore, if either of those
        # are used then well save the genre column accordingly.
        if genre == 'hip' or genre == 'hop':
            all_artists_ids['genres'] = 'hip-hop'
        else:
            all_artists_ids['genres'] = genre

        # All of the columns that are strings are converted to them.
        # When the raw data is returned from the API it is not coming back
        # as a proper string, and therefore cannot be put into a SQL database.

        all_artists_ids[['divisions', 'has_upcoming_events', 'home_venue_id', 'id', 'image', 'images.huge',
                         'links', 'name', 'score', 'short_name', 'slug', 'stats.event_count', 
                         'type', 'url']] = all_artists_ids[['divisions', 'has_upcoming_events', 'home_venue_id',
                                                            'id', 'image', 'images.huge', 'links', 'name', 
                                                            'score', 'short_name', 'slug', 'stats.event_count',
                                                            'type', 'url']].astype('str')

        # Set the is as the index colum. All ids are (or should be) unique
        all_artists_ids = all_artists_ids.set_index('id')

        # Append the data collected to the artist database
        all_artists_ids.to_sql('all_artist_data', 'sqlite:///ticket_touting.db', if_exists='append', index=True, index_label='id')

        # Now That the data has been appended lets de-duplicate our table
        # To do this I am going to conncect to the data base:
        con = sqlite3.connect('ticket_touting.db')
        cur = con.cursor()

        # Then query the the artist table, only selecting distinc/unique instances
        query = "SELECT DISTINCT * FROM all_artist_data"
        cur.execute(query)

        # From there I will execute the query and save it as a dataframe with the
        # the appropriate columns
        column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                        'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

        # Once the 'fect' is executed with the correct columns I am going
        # to set the 'id' column as the index, and then push all of the
        # distinct/unique artist to the 'all_artists_data' table within
        # the 'ticket_touting' database

        pd.DataFrame(cur.fetchall(),
                     columns=column_names).set_index('id').to_sql('all_artist_data',
                                                                  'sqlite:///ticket_touting.db',
                                                                  if_exists='replace', index=True, index_label='id')
        return 'Finished adding {} artists!'.format(genre)
    
    except: 
        print '''This is an incorrect genre.
       \nYou should make sure that your genre does not have any spaces or special characters.'''

# %% [markdown]
# # Test
#
# Let's get data for just the electronic artist and see a snapshot of the stored data.

# %%
get_artist_by_genre('electronic')
# Out:
# 'Finished adding electronic artists!'

# %%
# Now That the data has been appended lets de-duplicate our table
# To do this I am going to conncect to the data base:

con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()

# Then query the the artist table, only selecting distinc/unique instances
query_test = "SELECT * FROM all_artist_data LIMIT 3"
cur.execute(query_test)

# From there I will execute the query and save it as a dataframe with the
# the appropriate columns
column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                    'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

# Once the 'fect' is executed with the correct columns I am going
# to set the 'id' column as the index.

pd.DataFrame(cur.fetchall(),
             columns=column_names).set_index('id')
# Out:
#       divisions has_upcoming_events home_venue_id  \
# id
# 7960        nan               False           nan
# 38619       nan               False           nan
# 25737       nan               False           nan
#
#                                                    image  \
# id
# 7960   https://chairnerd.global.ssl.fastly.net/images...
# 38619                                                nan
# 25737                                                nan
#
#                                              images.huge links  \
# id
# 7960   https://chairnerd.global.ssl.fastly.net/images...    []
# 38619                                                nan    []
# 25737                                                nan    []
#
#                       name     score           short_name  \
# id
# 7960   Swedish House Mafia  0.734832  Swedish House Mafia
# 38619               Sinden  0.691532               Sinden
# 25737      Trent Cantrelle  0.691532      Trent Cantrelle
#
#                       slug stats.event_count  type  \
# id
# 7960   swedish-house-mafia                 0  band
# 38619               sinden                 0  band
# 25737      trent-cantrelle                 0  band
#
#                                                     url      genres
# id
# 7960   https://seatgeek.com/swedish-house-mafia-tickets  electronic
# 38619               https://seatgeek.com/sinden-tickets  electronic
# 25737      https://seatgeek.com/trent-cantrelle-tickets  electronic

# %% [markdown]
# # Voilà! Let's get everything
#
# - Now that it worked lets collect all artist information and store it into a SQL database.
# - We will be able to use that data later to collect other data.
#     - I've noticed that SeatGeek's API has trouble return results if the genre has a space or special character in it. For that reason Rock will all be stored as one genre, and 'Hip' is short for hip-hop.

# %%
all_seetgeek_genres = ['Alternative', 'Rock', 'Country', 'Electronic', 'Hip',
                       'Indie', 'Pop', 'Rnb', 'Alternative', 'Blues', 'Classical',
                       'Folk', 'Jazz', 'Latin', 'Punk', 'Rap', 'Reggae', 'Soul']

# %%
for i in range(pd.DataFrame(all_seetgeek_genres).shape[0]):
    print all_seetgeek_genres[i]
    get_artist_by_genre(all_seetgeek_genres[i])
# Out:
# Alternative
# Rock
# Country
# Electronic
# Hip
# Indie
# Pop
# Rnb
# Alternative
# Blues
# Classical
# Folk
# Jazz
# Latin
# Punk
# Rap
# Reggae
# Soul

# %% [markdown]
# # Next up, more data!
# Now that I have collected all artist information I'm going to use that in order to collected data for all concerts for earch artist.

# %% [markdown]
# **I will use the genre names from the SQL artist table in order to search seetgeek's api.**

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query_test = "SELECT DISTINCT genres FROM all_artist_data"
cur.execute(query_test)
all_seetgeek_genres = pd.DataFrame(cur.fetchall())
all_seetgeek_genres
# Out:
#               0
# 0    electronic
# 1       hip-hop
# 2   alternative
# 3          rock
# 4       country
# 5         indie
# 6           pop
# 7           rnb
# 8         blues
# 9     classical
# 10         folk
# 11         jazz
# 12        latin
# 13         punk
# 14          rap
# 15       reggae
# 16         soul

# %% [markdown]
# **I'm using the distinct genres to search through the SQL table. The way that I will search and get results is shown in the code below. This code will be used in a function.**

# %%
query_test = "SELECT * FROM all_artist_data WHERE genres = '{}'".format(distinct_genres['genres'][0])
cur.execute(query_test)

# From there I will execute the query and save it as a dataframe with the
# the appropriate columns
column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                    'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

# Once the 'fect' is executed with the correct columns I am going
# to set the 'id' column as the index.

x = pd.DataFrame(cur.fetchall(),
             columns=column_names).set_index('id')

# %%
x
# Out:
#        divisions has_upcoming_events home_venue_id  \
# id
# 7960         nan               False           nan
# 38619        nan               False           nan
# 25737        nan               False           nan
# 18965        nan                True           nan
# 58199        nan               False           nan
# 22817        nan               False           nan
# 33619        nan                True           nan
# 17603        nan                True           nan
# 16783        nan                True           nan
# 34242        nan               False           nan
# 11721        nan               False           nan
# 22631        nan                True           nan
# 55540        nan               False           nan
# 22866        nan               False           nan
# 42876        nan                True           nan
# 22449        nan                True           nan
# 24940        nan                True           nan
# 85298        nan                True           nan
# 41374        nan                True           nan
# 22512        nan               False           nan
# 22617        nan                True           nan
# 24048        nan               False           nan
# 18124        nan                True           nan
# 22815        nan                True           nan
# 235786       nan               False           nan
# 23393        nan                True           nan
# 13665        nan               False           nan
# 22576        nan                True           nan
# 27139        nan                True           nan
# 32201        nan               False           nan
# ...          ...                 ...           ...
# 450879       nan               False           nan
# 450881       nan               False           nan
# 450867       nan               False           nan
# 450778       nan               False           nan
# 451271       nan               False           nan
# 364892       nan                True           nan
# 20738        nan                True           nan
# 247593       nan                True           nan
# 31350        nan                True           nan
# 23915        nan                True           nan
# 134088       nan                True           nan
# 97693        nan                True           nan
# 111444       nan                True           nan
# 10256        nan                True           nan
# 22570        nan                True           nan
# 22175        nan                True           nan
# 22724        nan                True           nan
# 4129         nan                True           nan
# 77779        nan                True           nan
# 335898       nan                True           nan
# 303756       nan                True           nan
# 19508        nan                True           nan
# 16281        nan                True           nan
# 4487         nan                True           nan
# 19114        nan                True           nan
# 27977        nan                True           nan
# 23261        nan                True           nan
# 22581        nan                True           nan
# 287274       nan               False           nan
# 12420        nan                True           nan
#
#                                                     image  \
# id
# 7960    https://chairnerd.global.ssl.fastly.net/images...
# 38619                                                 nan
# 25737                                                 nan
# 18965                                                 nan
# 58199   https://chairnerd.global.ssl.fastly.net/images...
# 22817                                                 nan
# 33619                                                 nan
# 17603   https://chairnerd.global.ssl.fastly.net/images...
# 16783                                                 nan
# 34242   https://chairnerd.global.ssl.fastly.net/images...
# 11721                                                 nan
# 22631                                                 nan
# 55540   https://chairnerd.global.ssl.fastly.net/images...
# 22866   https://chairnerd.global.ssl.fastly.net/images...
# 42876                                                 nan
# 22449   https://chairnerd.global.ssl.fastly.net/images...
# 24940   https://chairnerd.global.ssl.fastly.net/images...
# 85298                                                 nan
# 41374                                                 nan
# 22512                                                 nan
# 22617                                                 nan
# 24048   https://chairnerd.global.ssl.fastly.net/images...
# 18124                                                 nan
# 22815   https://chairnerd.global.ssl.fastly.net/images...
# 235786  https://chairnerd.global.ssl.fastly.net/images...
# 23393                                                 nan
# 13665   https://chairnerd.global.ssl.fastly.net/images...
# 22576                                                 nan
# 27139                                                 nan
# 32201   https://chairnerd.global.ssl.fastly.net/images...
# ...                                                   ...
# 450879                                                nan
# 450881                                                nan
# 450867                                                nan
# 450778                                                nan
# 451271                                                nan
# 364892                                                nan
# 20738                                                 nan
# 247593                                                nan
# 31350                                                 nan
# 23915                                                 nan
# 134088                                                nan
# 97693                                                 nan
# 111444  https://chairnerd.global.ssl.fastly.net/images...
# 10256   https://chairnerd.global.ssl.fastly.net/images...
# 22570   https://chairnerd.global.ssl.fastly.net/images...
# 22175   https://chairnerd.global.ssl.fastly.net/images...
# 22724   https://chairnerd.global.ssl.fastly.net/images...
# 4129    https://chairnerd.global.ssl.fastly.net/images...
# 77779   https://chairnerd.global.ssl.fastly.net/images...
# 335898                                                nan
# 303756                                                nan
# 19508   https://chairnerd.global.ssl.fastly.net/images...
# 16281   https://chairnerd.global.ssl.fastly.net/images...
# 4487    https://chairnerd.global.ssl.fastly.net/images...
# 19114                                                 nan
# 27977                                                 nan
# 23261                                                 nan
# 22581                                                 nan
# 287274                                                nan
# 12420   https://chairnerd.global.ssl.fastly.net/images...
#
#                                               images.huge links  \
# id
# 7960    https://chairnerd.global.ssl.fastly.net/images...    []
# 38619                                                 nan    []
# 25737                                                 nan    []
# 18965                                                 nan    []
# 58199   https://chairnerd.global.ssl.fastly.net/images...    []
# 22817                                                 nan    []
# 33619                                                 nan    []
# 17603   https://chairnerd.global.ssl.fastly.net/images...    []
# 16783                                                 nan    []
# 34242   https://chairnerd.global.ssl.fastly.net/images...    []
# 11721                                                 nan    []
# 22631                                                 nan    []
# 55540   https://chairnerd.global.ssl.fastly.net/images...    []
# 22866   https://chairnerd.global.ssl.fastly.net/images...    []
# 42876                                                 nan    []
# 22449   https://chairnerd.global.ssl.fastly.net/images...    []
# 24940   https://chairnerd.global.ssl.fastly.net/images...    []
# 85298                                                 nan    []
# 41374                                                 nan    []
# 22512                                                 nan    []
# 22617                                                 nan    []
# 24048   https://chairnerd.global.ssl.fastly.net/images...    []
# 18124                                                 nan    []
# 22815   https://chairnerd.global.ssl.fastly.net/images...    []
# 235786  https://chairnerd.global.ssl.fastly.net/images...    []
# 23393                                                 nan    []
# 13665   https://chairnerd.global.ssl.fastly.net/images...    []
# 22576                                                 nan    []
# 27139                                                 nan    []
# 32201   https://chairnerd.global.ssl.fastly.net/images...    []
# ...                                                   ...   ...
# 450879                                                nan    []
# 450881                                                nan    []
# 450867                                                nan    []
# 450778                                                nan    []
# 451271                                                nan    []
# 364892                                                nan    []
# 20738                                                 nan    []
# 247593                                                nan    []
# 31350                                                 nan    []
# 23915                                                 nan    []
# 134088                                                nan    []
# 97693                                                 nan    []
# 111444  https://chairnerd.global.ssl.fastly.net/images...    []
# 10256   https://chairnerd.global.ssl.fastly.net/images...    []
# 22570   https://chairnerd.global.ssl.fastly.net/images...    []
# 22175   https://chairnerd.global.ssl.fastly.net/images...    []
# 22724   https://chairnerd.global.ssl.fastly.net/images...    []
# 4129    https://chairnerd.global.ssl.fastly.net/images...    []
# 77779   https://chairnerd.global.ssl.fastly.net/images...    []
# 335898                                                nan    []
# 303756                                                nan    []
# 19508   https://chairnerd.global.ssl.fastly.net/images...    []
# 16281   https://chairnerd.global.ssl.fastly.net/images...    []
# 4487    https://chairnerd.global.ssl.fastly.net/images...    []
# 19114                                                 nan    []
# 27977                                                 nan    []
# 23261                                                 nan    []
# 22581                                                 nan    []
# 287274                                                nan    []
# 12420   https://chairnerd.global.ssl.fastly.net/images...    []
#
#                                   name     score  \
# id
# 7960               Swedish House Mafia  0.734832
# 38619                           Sinden  0.691532
# 25737                  Trent Cantrelle  0.691532
# 18965                      Nina Kraviz   0.68924
# 58199                   Lady Starlight  0.687344
# 22817                        Huoratron  0.678964
# 33619                  Laurent Garnier  0.678358
# 17603                        Sensation  0.665095
# 16783                     Lee Burridge  0.661718
# 34242                        Zane Lowe  0.661716
# 11721                    Factory Floor  0.661541
# 22631                          Solomun  0.654417
# 55540                            MitiS  0.654335
# 22866                            Dixon   0.64988
# 42876            The Martinez Brothers  0.648394
# 22449                           Dub FX  0.648369
# 24940                        Icona Pop  0.648312
# 85298                   Flint Eastwood  0.647575
# 41374                             Tiga  0.645034
# 22512                    Tiger & Woods  0.644484
# 22617                       Guy Gerber   0.64267
# 24048                      The 2 Bears  0.638333
# 18124                            Scuba  0.637685
# 22815                    Birdy Nam Nam  0.636601
# 235786                            Arca  0.635978
# 23393                   Damian Lazarus  0.634434
# 13665                        The Knife  0.634124
# 22576                             AN21  0.633176
# 27139                           Kastle  0.632444
# 32201                               UZ  0.630909
# ...                                ...       ...
# 450879                         FLT RSK       0.0
# 450881                         DJ Show       0.0
# 450867  Freakout! 8th Annual Halloween       0.0
# 450778                 Loud Mouth Bass       0.0
# 451271                       Hot Mix 5       0.0
# 364892                      Leo Kalyan       0.0
# 20738                          Behrouz       0.0
# 247593                Telefon Tel Aviv       0.0
# 31350                        Sepalcure       0.0
# 23915                            Kode9       0.0
# 134088                    Juno Reactor       0.0
# 97693                       Todd Terry       0.0
# 111444                    Hot Since 82  0.617499
# 10256                           Avicii  0.604152
# 22570                    Richie Hawtin  0.595175
# 22175                         Jamie xx  0.580439
# 22724                  Maya Jane Coles  0.578099
# 4129                          Four Tet  0.561001
# 77779                           Deorro  0.525987
# 335898              The Japanese House  0.512187
# 303756                        Big Wild  0.503227
# 19508                           Zomboy  0.486833
# 16281                            Nervo  0.482314
# 4487                    Penguin Prison  0.481415
# 19114                     Foam N' Glow  0.358793
# 27977                  Floating Points   0.35647
# 23261                       Random Rab  0.340042
# 22581                    Sidney Samson   0.29782
# 287274                      Night Bass       0.0
# 12420                      Morgan Page  0.470756
#
#                             short_name                           slug  \
# id
# 7960               Swedish House Mafia            swedish-house-mafia
# 38619                           Sinden                         sinden
# 25737                  Trent Cantrelle                trent-cantrelle
# 18965                      Nina Kraviz                    nina-kraviz
# 58199                   Lady Starlight                 lady-starlight
# 22817                        Huoratron                      huoratron
# 33619                  Laurent Garnier                laurent-garnier
# 17603                        Sensation                      sensation
# 16783                     Lee Burridge                   lee-burridge
# 34242                        Zane Lowe                      zane-lowe
# 11721                    Factory Floor                  factory-floor
# 22631                          Solomun                        solomun
# 55540                            MitiS                          mitis
# 22866                            Dixon                          dixon
# 42876            The Martinez Brothers          the-martinez-brothers
# 22449                           Dub FX                         dub-fx
# 24940                        Icona Pop                      icona-pop
# 85298                   Flint Eastwood                 flint-eastwood
# 41374                             Tiga                           tiga
# 22512                    Tiger & Woods                    tiger-woods
# 22617                       Guy Gerber                     guy-gerber
# 24048                      The 2 Bears                    the-2-bears
# 18124                            Scuba                          scuba
# 22815                    Birdy Nam Nam                  birdy-nam-nam
# 235786                            Arca                           arca
# 23393                   Damian Lazarus                 damian-lazarus
# 13665                        The Knife                      the-knife
# 22576                             AN21                           an21
# 27139                           Kastle                         kastle
# 32201                               UZ                             uz
# ...                                ...                            ...
# 450879                         FLT RSK                        flt-rsk
# 450881                         DJ Show                        dj-show
# 450867  Freakout! 8th Annual Halloween  freakout-8th-annual-halloween
# 450778                 Loud Mouth Bass                loud-mouth-bass
# 451271                       Hot Mix 5                      hot-mix-5
# 364892                      Leo Kalyan                     leo-kalyan
# 20738                          Behrouz                        behrouz
# 247593                Telefon Tel Aviv               telefon-tel-aviv
# 31350                        Sepalcure                      sepalcure
# 23915                            Kode9                          kode9
# 134088                    Juno Reactor                   juno-reactor
# 97693                       Todd Terry                     todd-terry
# 111444                    Hot Since 82                   hot-since-82
# 10256                           Avicii                         avicii
# 22570                    Richie Hawtin                  richie-hawtin
# 22175                         Jamie xx                       jamie-xx
# 22724                  Maya Jane Coles                maya-jane-coles
# 4129                          Four Tet                       four-tet
# 77779                           Deorro                         deorro
# 335898              The Japanese House             the-japanese-house
# 303756                        Big Wild                       big-wild
# 19508                           Zomboy                         zomboy
# 16281                            Nervo                          nervo
# 4487                    Penguin Prison                 penguin-prison
# 19114                     Foam N' Glow                    foam-n-glow
# 27977                  Floating Points                floating-points
# 23261                       Random Rab                     random-rab
# 22581                    Sidney Samson                  sidney-samson
# 287274                      Night Bass                     night-bass
# 12420                      Morgan Page                    morgan-page
#
#        stats.event_count  type  \
# id
# 7960                   0  band
# 38619                  0  band
# 25737                  0  band
# 18965                  1  band
# 58199                  0  band
# 22817                  0  band
# 33619                  1  band
# 17603                  4  band
# 16783                  4  band
# 34242                  0  band
# 11721                  0  band
# 22631                  1  band
# 55540                  0  band
# 22866                  0  band
# 42876                  5  band
# 22449                  5  band
# 24940                  1  band
# 85298                  6  band
# 41374                  2  band
# 22512                  0  band
# 22617                  1  band
# 24048                  0  band
# 18124                  2  band
# 22815                  1  band
# 235786                 0  band
# 23393                  3  band
# 13665                  0  band
# 22576                  1  band
# 27139                  1  band
# 32201                  0  band
# ...                  ...   ...
# 450879                 0  band
# 450881                 0  band
# 450867                 0  band
# 450778                 0  band
# 451271                 0  band
# 364892                 1  band
# 20738                  2  band
# 247593                 5  band
# 31350                  1  band
# 23915                  2  band
# 134088                 1  band
# 97693                 13  band
# 111444                 5  band
# 10256                 19  band
# 22570                  2  band
# 22175                 14  band
# 22724                  2  band
# 4129                  17  band
# 77779                  6  band
# 335898                14  band
# 303756                16  band
# 19508                  7  band
# 16281                  8  band
# 4487                   2  band
# 19114                  1  band
# 27977                 13  band
# 23261                  2  band
# 22581                  3  band
# 287274                 0  band
# 12420                  5  band
#
#                                                       url      genres
# id
# 7960     https://seatgeek.com/swedish-house-mafia-tickets  electronic
# 38619                 https://seatgeek.com/sinden-tickets  electronic
# 25737        https://seatgeek.com/trent-cantrelle-tickets  electronic
# 18965            https://seatgeek.com/nina-kraviz-tickets  electronic
# 58199         https://seatgeek.com/lady-starlight-tickets  electronic
# 22817              https://seatgeek.com/huoratron-tickets  electronic
# 33619        https://seatgeek.com/laurent-garnier-tickets  electronic
# 17603              https://seatgeek.com/sensation-tickets  electronic
# 16783           https://seatgeek.com/lee-burridge-tickets  electronic
# 34242              https://seatgeek.com/zane-lowe-tickets  electronic
# 11721          https://seatgeek.com/factory-floor-tickets  electronic
# 22631                https://seatgeek.com/solomun-tickets  electronic
# 55540                  https://seatgeek.com/mitis-tickets  electronic
# 22866                  https://seatgeek.com/dixon-tickets  electronic
# 42876   https://seatgeek.com/the-martinez-brothers-tic...  electronic
# 22449                 https://seatgeek.com/dub-fx-tickets  electronic
# 24940              https://seatgeek.com/icona-pop-tickets  electronic
# 85298         https://seatgeek.com/flint-eastwood-tickets  electronic
# 41374                   https://seatgeek.com/tiga-tickets  electronic
# 22512            https://seatgeek.com/tiger-woods-tickets  electronic
# 22617             https://seatgeek.com/guy-gerber-tickets  electronic
# 24048            https://seatgeek.com/the-2-bears-tickets  electronic
# 18124                  https://seatgeek.com/scuba-tickets  electronic
# 22815          https://seatgeek.com/birdy-nam-nam-tickets  electronic
# 235786                  https://seatgeek.com/arca-tickets  electronic
# 23393         https://seatgeek.com/damian-lazarus-tickets  electronic
# 13665              https://seatgeek.com/the-knife-tickets  electronic
# 22576                   https://seatgeek.com/an21-tickets  electronic
# 27139                 https://seatgeek.com/kastle-tickets  electronic
# 32201                     https://seatgeek.com/uz-tickets  electronic
# ...                                                   ...         ...
# 450879               https://seatgeek.com/flt-rsk-tickets  electronic
# 450881               https://seatgeek.com/dj-show-tickets  electronic
# 450867  https://seatgeek.com/freakout-8th-annual-hallo...  electronic
# 450778       https://seatgeek.com/loud-mouth-bass-tickets  electronic
# 451271             https://seatgeek.com/hot-mix-5-tickets  electronic
# 364892            https://seatgeek.com/leo-kalyan-tickets  electronic
# 20738                https://seatgeek.com/behrouz-tickets  electronic
# 247593      https://seatgeek.com/telefon-tel-aviv-tickets  electronic
# 31350              https://seatgeek.com/sepalcure-tickets  electronic
# 23915                  https://seatgeek.com/kode9-tickets  electronic
# 134088          https://seatgeek.com/juno-reactor-tickets  electronic
# 97693             https://seatgeek.com/todd-terry-tickets  electronic
# 111444          https://seatgeek.com/hot-since-82-tickets  electronic
# 10256                 https://seatgeek.com/avicii-tickets  electronic
# 22570          https://seatgeek.com/richie-hawtin-tickets  electronic
# 22175               https://seatgeek.com/jamie-xx-tickets  electronic
# 22724        https://seatgeek.com/maya-jane-coles-tickets  electronic
# 4129                https://seatgeek.com/four-tet-tickets  electronic
# 77779                 https://seatgeek.com/deorro-tickets  electronic
# 335898    https://seatgeek.com/the-japanese-house-tickets  electronic
# 303756              https://seatgeek.com/big-wild-tickets  electronic
# 19508                 https://seatgeek.com/zomboy-tickets  electronic
# 16281                  https://seatgeek.com/nervo-tickets  electronic
# 4487          https://seatgeek.com/penguin-prison-tickets  electronic
# 19114            https://seatgeek.com/foam-n-glow-tickets  electronic
# 27977        https://seatgeek.com/floating-points-tickets  electronic
# 23261             https://seatgeek.com/random-rab-tickets  electronic
# 22581          https://seatgeek.com/sidney-samson-tickets  electronic
# 287274            https://seatgeek.com/night-bass-tickets  electronic
# 12420            https://seatgeek.com/morgan-page-tickets  electronic
#
# [1825 rows x 14 columns]

# %% [markdown]
# **I'm making a function to do this data collection**

# %%
x.shape[0]
# Out:
# 1825

# %%
def get_concert_by_artist(genre_in_database):
    con = sqlite3.connect('ticket_touting.db')
    cur = con.cursor()
    query = "SELECT id, genres, short_name FROM all_artist_data WHERE genres = '{}'".format(genre_in_database)
    cur.execute(query)
    x = pd.DataFrame(cur.fetchall(),columns=['id', 'genres', 'short_name'])
    
    master_concerts = pd.DataFrame()
    
    for i in range(x.shape[0]):
        try:    
            artist_concert_info = "https://api.seatgeek.com/2/events?performers.id={}&client_id=NDQxMDA3NXwxNDU5MDI4MzEx&per_page=5000&datetime_utc.gt=2012-01-01".format(
                x['id'][i])

            r = requests.get(artist_concert_info)
            json_concert_per_artist = r.json()
            y = json_normalize(json_concert_per_artist)
            if y['events'][0] != []:
                single_artist_df = json_normalize(y['events'][0])
                single_artist_df['artist_name'] = x['short_name'][i]
                single_artist_df['artist_id'] = x['id'][i]
                single_artist_df['artist_genre'] = x['genres'][i]
                master_concerts = master_concerts.append(single_artist_df)
                


        except:
            'placeholder'
            
        if i % 50 == 0:
            print 'Searching #{} out of {}'.format(i, x.shape[0])
                

    # We will only put the data into a SQL database 
    # once all of the data has been collected.
    # Once the data is added to the database then we will run a 
    # distinct SQL function in order to de-duplicate the data

    print 'Making the database for {}'.format(genre_in_database)

    master_concerts = master_concerts.drop(['links', 'performers',
                                            'taxonomies', 'venue.links',
                                            'venue.url'], 1).set_index('id')
    master_concerts.to_sql('all_concert_data', 'sqlite:///ticket_touting.db',
                       if_exists='append', index=True, index_label='id')

    print 'Making the de-duplicated database!'

    # Now That the data has been appended lets de-duplicate our table
    # To do this I am going to conncect to the data base:
    con = sqlite3.connect('ticket_touting.db')
    cur = con.cursor()

    # Then query the the artist table, only selecting distinc/unique instances
    query = "SELECT DISTINCT * FROM all_concert_data"
    cur.execute(query)

    # From there I will execute the query and save it as a dataframe with the
    # the appropriate columns
    column_names = ['id', 'announce_date', 'created_at', 'date_tbd', 'datetime_local', 'datetime_tbd',
                    'datetime_utc', 'general_admission', 'score','short_title','stats.average_price',
                     'stats.highest_price','stats.listing_count','stats.lowest_price', 
                    'stats.lowest_price_good_deals','time_tbd','title','type','url','venue.address',
                    'venue.city','venue.country','venue.display_location','venue.extended_address',
                    'venue.id','venue.location.lat','venue.location.lon','venue.name',
                    'venue.postal_code','venue.score','venue.slug', 'venue.state', 
                    'venue.timezone','visible_until_utc','artist_name','artist_id','artist_genre']



    # Once the 'fect' is executed with the correct columns I am going
    # to set the 'id' column as the index, and then push all of the
    # distinct/unique artist to the 'all_artists_data' table within
    # the 'ticket_touting' database

    pd.DataFrame(cur.fetchall(),
                 columns=column_names).set_index('id').to_sql('all_concert_data',
                                                              'sqlite:///ticket_touting.db',
                                                              if_exists='replace', index=True, index_label='id')

    return 'Done!'

# %%
get_concert_by_artist('electronic')
# Out:
# Searching #0 out of 1825
# Searching #50 out of 1825
# Searching #100 out of 1825
# Searching #150 out of 1825
# Searching #200 out of 1825
# Searching #250 out of 1825
# Searching #300 out of 1825
# Searching #350 out of 1825
# Searching #400 out of 1825
# Searching #450 out of 1825
# Searching #500 out of 1825
# Searching #550 out of 1825
# Searching #600 out of 1825
# Searching #650 out of 1825
# Searching #700 out of 1825
# Searching #750 out of 1825
# Searching #800 out of 1825
# Searching #850 out of 1825
# Searching #900 out of 1825
# Searching #950 out of 1825
# Searching #1000 out of 1825
# Searching #1050 out of 1825
# Searching #1100 out of 1825
# Searching #1150 out of 1825
# Searching #1200 out of 1825
# Searching #1250 out of 1825
# Searching #1300 out of 1825
# Searching #1350 out of 1825
# Searching #1400 out of 1825
# Searching #1450 out of 1825
# Searching #1500 out of 1825
# Searching #1550 out of 1825
# Searching #1600 out of 1825
# Searching #1650 out of 1825
# Searching #1700 out of 1825
# Searching #1750 out of 1825
# Searching #1800 out of 1825
# Making the database for electronic
# Making the de-duplicated database!
# 'Done!'

# %% [markdown]
# Let's do a query and make sure the data stored properly

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query = "SELECT * FROM all_concert_data"
cur.execute(query)

column_names = ['id', 'announce_date', 'created_at', 'date_tbd', 'datetime_local', 'datetime_tbd',
                'datetime_utc', 'general_admission', 'score','short_title','stats.average_price',
                 'stats.highest_price','stats.listing_count','stats.lowest_price', 
                'stats.lowest_price_good_deals','time_tbd','title','type','url','venue.address',
                'venue.city','venue.country','venue.display_location','venue.extended_address',
                'venue.id','venue.location.lat','venue.location.lon','venue.name',
                'venue.postal_code','venue.score','venue.slug', 'venue.state', 
# 3262702                       Sonny Fodera with Todd Terry
# 3100376                                         Todd Terry
# 3198041                                         Todd Terry
# 3100380                                         Todd Terry
# 3096190                     Todd Terry with Danny Rampling
# 3100379                                         Todd Terry
# 3100378                                         Todd Terry
# 2947472  Sasquatch! Festival (4 Day Pass) with Kurt Vil...
# 2648054  Governors Ball Music Festival (3 Day Pass) wit...
# 2952955                   The 1975 with The Japanese House
#
#         stats.average_price     ...                        venue.name  \
# id                              ...
# 3155401                None     ...                              DC10
# 3265144                None     ...                  Razzmatazz Clubs
# 3228287                None     ...                        Sloterpark
# 3062766                None     ...                    Clapham Common
# 3265400                None     ...                Fox Theater Pomona
# 3225074                25.5     ...                    Beta Nightclub
# 3264577                None     ...                           Populux
# 3138871                None     ...                              XOYO
# 3219118                None     ...            New Mountain Asheville
# 3187033                None     ...                          B Ryders
# 2989090                None     ...                 Olimpiisky Palace
# 3141923                None     ...                   Amsterdam Arena
# 3163348                None     ...                        Storm Club
# 3192445                None     ...       San Antonio Recreation Area
# 3260460                None     ...                   Brooklyn Mirage
# 3260504                None     ...             Hotel Silken Diagonal
# 3199064                None     ...                           D! CLUB
# 3230390                None     ...                         Bang Bang
# 3229692                None     ...                   Sound Nightclub
# 2945603               455.0     ...                        Citi Field
# 3155401                None     ...                              DC10
# 3049128                None     ...             Damyns Hall Aerodrome
# 3201183                None     ...        Ship Point (Inner Harbour)
# 3201182                None     ...        Ship Point (Inner Harbour)
# 3201111                None     ...            Garibaldi Lift Company
# 3253292                23.0     ...                          Newspeak
# 3142502                None     ...                          Magnolia
# 3204098                48.0     ...               FirstEnergy Stadium
# 3210626                None     ...                     Ottawa Tavern
# 3223840                None     ...                         The Hi Fi
# ...                     ...     ...                               ...
# 3124892               465.0     ...                 Parc Jean-Drapeau
# 3252001                None     ...                The Pickle Factory
# 3259645                None     ...                      Public Works
# 3140863                None     ...                       La Terrazza
# 3235417                None     ...                  Knitting Factory
# 3038537                72.0     ...                     Vogue Theatre
# 3038504                67.0     ...                       The Showbox
# 3038381                81.0     ...                     Fonda Theatre
# 3262450                None     ...                        The Parish
# 3252660                None     ...                          Echoplex
# 3233696                None     ...                       Trans-Pecos
# 3264537                None     ...                   Union Nightclub
# 3245727                None     ...                     The Crocodile
# 3262039                None     ...               Brixx Bar and Grill
# 3190593                None     ...             Les Terrasses du Port
# 3146873                None     ...                       Pacha Ibiza
# 3198610                None     ...                              CDLC
# 3100377                None     ...                       Space Ibiza
# 3262469                None     ...                          Stage 48
# 3199950                None     ...                           Sankeys
# 3262702                None     ...                     Sankeys Ibiza
# 3100376                None     ...                       Space Ibiza
# 3198041                None     ...                             Praja
# 3100380                None     ...                       Space Ibiza
# 3096190                None     ...                     Sankeys Ibiza
# 3100379                None     ...                       Space Ibiza
# 3100378                None     ...                       Space Ibiza
# 2947472               430.0     ...                Gorge Amphitheatre
# 2648054               465.5     ...                   Randalls Island
# 2952955                88.0     ...            Red Rocks Amphitheatre
#
#          venue.postal_code venue.score                   venue.slug  \
# id
# 3155401              07816    0.000000                         dc10
# 3265144              08018    0.000000             razzmatazz-clubs
# Searching #3550 out of 5000
# Searching #3600 out of 5000
# Searching #3650 out of 5000
# Searching #3700 out of 5000
# Searching #3750 out of 5000
# Searching #3800 out of 5000
# Searching #3850 out of 5000
# Searching #3900 out of 5000
# Searching #3950 out of 5000
# Searching #4000 out of 5000
# Searching #4050 out of 5000
# Searching #4100 out of 5000
# Searching #4150 out of 5000
# Searching #4200 out of 5000
# Searching #4250 out of 5000
# Searching #4300 out of 5000
# Searching #4350 out of 5000
# Searching #4400 out of 5000
# Searching #4450 out of 5000
# Searching #4500 out of 5000
# Searching #4550 out of 5000
# Searching #4600 out of 5000
# Searching #4650 out of 5000
# Searching #4700 out of 5000
# Searching #4750 out of 5000
# Searching #4800 out of 5000
# Searching #4850 out of 5000
# Searching #4900 out of 5000
# Searching #4950 out of 5000
# Making the database for alternative
# Making the de-duplicated database!
# rock
# Searching #0 out of 5000
# Searching #50 out of 5000
# Searching #100 out of 5000
# Searching #150 out of 5000
# Searching #200 out of 5000
# Searching #250 out of 5000
# Searching #300 out of 5000
# Searching #350 out of 5000
# Searching #400 out of 5000
# Searching #450 out of 5000
# Searching #500 out of 5000
# Searching #550 out of 5000
# Searching #600 out of 5000
# Searching #650 out of 5000
# Searching #700 out of 5000
# Searching #750 out of 5000
# Searching #800 out of 5000
# Searching #850 out of 5000
# Searching #900 out of 5000
# Searching #950 out of 5000
# Searching #1000 out of 5000
# Searching #1050 out of 5000
# Searching #1100 out of 5000
# Searching #1150 out of 5000
# Searching #1200 out of 5000
# Searching #1250 out of 5000
# Searching #1300 out of 5000
# Searching #1350 out of 5000
# Searching #1400 out of 5000
# Searching #1450 out of 5000
# Searching #1500 out of 5000
# Searching #1550 out of 5000
# Searching #1600 out of 5000
# Searching #1650 out of 5000
# Searching #1700 out of 5000
# Searching #1750 out of 5000
# Searching #1800 out of 5000
# Searching #1850 out of 5000
# Searching #1900 out of 5000
# Searching #1950 out of 5000
# Searching #2000 out of 5000
# Searching #2050 out of 5000
# Searching #2100 out of 5000
# Searching #2150 out of 5000
# Searching #2200 out of 5000
# Searching #2250 out of 5000
# Searching #2300 out of 5000
# Searching #2350 out of 5000
# Searching #2400 out of 5000
# Searching #2450 out of 5000
# Searching #2500 out of 5000
# Searching #2550 out of 5000
# Searching #2600 out of 5000
# Searching #2650 out of 5000
# Searching #2700 out of 5000
# Searching #2750 out of 5000
# Searching #2800 out of 5000
# Searching #2850 out of 5000
# Searching #2900 out of 5000
# Searching #2950 out of 5000
# Searching #3000 out of 5000
# Searching #3050 out of 5000
# Searching #3100 out of 5000
# Searching #3150 out of 5000
# Searching #3200 out of 5000
# Searching #3250 out of 5000
# Searching #3300 out of 5000
# Searching #3350 out of 5000
# Searching #3400 out of 5000
# Searching #3450 out of 5000
# Searching #3500 out of 5000
# Searching #3550 out of 5000
# Searching #3600 out of 5000
# Searching #3650 out of 5000
# Searching #3700 out of 5000
# Searching #3750 out of 5000
# Searching #3800 out of 5000
# Searching #3850 out of 5000
# Searching #3900 out of 5000
# Searching #3950 out of 5000
# Searching #4000 out of 5000
# Searching #4050 out of 5000
# Searching #100 out of 1225
# Searching #150 out of 1225
# Searching #200 out of 1225
# Searching #250 out of 1225
# Searching #300 out of 1225
# Searching #350 out of 1225
# Searching #400 out of 1225
# Searching #450 out of 1225
# Searching #500 out of 1225
# Searching #550 out of 1225
# Searching #600 out of 1225
# Searching #650 out of 1225
# Searching #700 out of 1225
# Searching #750 out of 1225
# Searching #800 out of 1225
# Searching #850 out of 1225
# Searching #900 out of 1225
# Searching #950 out of 1225
# Searching #1000 out of 1225
# Searching #1050 out of 1225
# Searching #1100 out of 1225
# Searching #1150 out of 1225
# Searching #1200 out of 1225
# Making the database for soul
# Making the de-duplicated database!

# %% [markdown]
# **I'm going to execute a couple of queries to make sure that the data is stored ok. First I will do a simple query a head of the dataframe. Then I'm going to ask for all of the unique genres within the table.**

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query = "SELECT * FROM all_concert_data limit 10"
cur.execute(query)

column_names = ['id', 'announce_date', 'created_at', 'date_tbd', 'datetime_local', 'datetime_tbd',
                'datetime_utc', 'general_admission', 'score','short_title','stats.average_price',
                 'stats.highest_price','stats.listing_count','stats.lowest_price', 
                'stats.lowest_price_good_deals','time_tbd','title','type','url','venue.address',
                'venue.city','venue.country','venue.display_location','venue.extended_address',
                'venue.id','venue.location.lat','venue.location.lon','venue.name',
                'venue.postal_code','venue.score','venue.slug', 'venue.state', 
                'venue.timezone','visible_until_utc','artist_name','artist_id','artist_genre']

pd.DataFrame(cur.fetchall(), columns=column_names).set_index('id')
# Out:
#                announce_date           created_at  date_tbd  \
# id
# 3155401  2016-03-16T00:00:00  2016-03-16T00:00:00         0
# 3265144  2016-05-01T00:00:00  2016-05-01T00:00:00         0
# 3228287  2016-04-12T00:00:00  2016-04-12T00:00:00         0
# 3062766  2016-01-28T00:00:00  2016-01-28T00:00:00         0
# 3265400  2016-05-01T00:00:00  2016-05-01T00:00:00         0
# 3225074  2016-04-11T00:00:00  2016-04-11T00:00:00         0
# 3264577  2016-05-01T00:00:00  2016-05-01T00:00:00         0
# 3138871  2016-03-07T00:00:00  2016-03-07T00:00:00         0
# 3219118  2016-04-10T00:00:00  2016-04-10T00:00:00         0
# 3187033  2016-03-28T00:00:00  2016-03-28T00:00:00         0
#
#               datetime_local  datetime_tbd         datetime_utc  \
# id
# 3155401  2016-05-23T03:30:00             0  2016-05-23T01:30:00
# 3265144  2016-06-17T03:30:00             0  2016-06-17T01:30:00
# 3228287  2016-08-13T12:00:00             0  2016-08-13T10:00:00
# 3062766  2016-08-28T11:00:00             0  2016-08-28T10:00:00
# 3265400  2016-05-14T15:00:00             0  2016-05-14T22:00:00
# 3225074  2016-05-29T17:00:00             0  2016-05-29T23:00:00
# 3264577  2016-05-30T23:00:00             0  2016-05-31T03:00:00
# 3138871  2016-05-07T21:00:00             0  2016-05-07T20:00:00
# 3219118  2016-05-07T21:00:00             0  2016-05-08T01:00:00
# 3187033  2016-05-18T20:00:00             0  2016-05-19T03:00:00
#
#          general_admission     score  \
# id
# 3155401                NaN  0.626239
# 3265144                NaN       NaN
# 3228287                NaN  0.000000
# 3062766                  1  0.615956
# 3265400                  1       NaN
# 3225074                NaN  0.648849
# 3264577                NaN       NaN
# 3138871                NaN  0.672708
# 3219118                NaN  0.658884
# 3187033                  1  0.380082
#
#                                                short_title  \
# id
# 3155401         Davide Squillace - Circoloco Opening Party
# 3265144       Nic Fanciulli with Damian Lazarus and Yousef
# 3228287    Loveland Festival with Damian Lazarus, Fur Coat
# 3062766  South West Four (SW4) Festival (Sunday Pass) w...
# 3265400                                             Sinden
# 3225074                               Nina Kraviz - Denver
# 3264577                            Nina Kraviz with Bjarki
# 3138871                                    Laurent Garnier
# 3219118                                          Sensation
# 3187033       Fortunate Youth with Peni Dean and Sensation
#
#         stats.average_price     ...                   venue.name  \
# id                              ...
# 3155401                None     ...                         DC10
# 3265144                None     ...             Razzmatazz Clubs
# 3228287                None     ...                   Sloterpark
# 3062766                None     ...               Clapham Common
# 3265400                None     ...           Fox Theater Pomona
# 3225074                25.5     ...               Beta Nightclub
# 3264577                None     ...                      Populux
# 3138871                None     ...                         XOYO
# 3219118                None     ...       New Mountain Asheville
# 3187033                None     ...                     B Ryders
#
#          venue.postal_code venue.score              venue.slug  venue.state  \
# id
# 3155401              07816    0.000000                    dc10           07
# 3265144              08018    0.000000        razzmatazz-clubs         None
# 3228287            1064 GW    0.000000              sloterpark         None
# 3062766                SW4    0.659543          clapham-common          Lbh
# 3265400              91766    0.617754      fox-theater-pomona           CA
# 3225074              80202    0.412814          beta-nightclub           CO
# 3264577              48201    0.461628                 populux           MI
# 3138871           EC2A 4AP    0.357290                    xoyo       London
# 3219118              28801    0.431002  new-mountain-asheville           NC
# 3187033              93309    0.458304                b-ryders           CA
#
#               venue.timezone    visible_until_utc      artist_name artist_id  \
# id
# 3155401        Europe/Madrid  2016-05-23T22:00:00   Damian Lazarus     23393
# 3265144        Europe/Madrid  2016-06-17T22:00:00   Damian Lazarus     23393
# 3228287     Europe/Amsterdam  2016-08-13T14:00:00   Damian Lazarus     23393
# 3062766        Europe/London  2016-08-28T14:00:00   Damian Lazarus     23393
# 3265400  America/Los_Angeles  2016-05-15T02:00:00           Sinden     38619
# 3225074       America/Denver  2016-05-30T03:00:00      Nina Kraviz     18965
# 3264577      America/Detroit  2016-05-31T07:00:00      Nina Kraviz     18965
# 3138871        Europe/London  2016-05-08T00:00:00  Laurent Garnier     33619
# 3219118     America/New_York  2016-05-08T05:00:00        Sensation     17603
# 3187033  America/Los_Angeles  2016-05-19T07:00:00        Sensation     17603
#
#         artist_genre
# id
# 3155401   electronic
# 3265144   electronic
# 3228287   electronic
# 3062766   electronic
# 3265400   electronic
# 3225074   electronic
# 3264577   electronic
# 3138871   electronic
# 3219118   electronic
# 3187033   electronic
#
# [10 rows x 36 columns]

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query = "SELECT DISTINCT artist_genre FROM all_concert_data"
cur.execute(query)

column_names = ['artist_genre']

pd.DataFrame(cur.fetchall(), columns=column_names)
# Out:
#    artist_genre
# 0    electronic
# 1       hip-hop
# 2   alternative
# 3          rock
# 4       country
# 5         indie
# 6           pop
# 7           rnb
# 8         blues
# 9     classical
# 10         folk
# 11         jazz
# 12        latin
# 13         punk
# 14          rap
# 15       reggae
# 16         soul
