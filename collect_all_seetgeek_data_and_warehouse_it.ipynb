# %%
import pandas as pd
import sqlalchemy
from sqlalchemy import create_engine # database connection
import sqlite3
from pandas.io.json import json_normalize
import requests

# %% [markdown]
# # Create database
#
# This step should only be execute the first time. After the database has been created the first time, then creating a database is deprecated. If we create the database again we will acidentially lose of the the prior data we have collected.

# %%
# create a database that will hold all ticket touting information
# e.g. table for artist_ids and information, 
# table for concerts affiliated for a particular genre, etc.

# Initializes database with filename 311_8M.db in current directory

### THIS IS THE LINE TO RUN TO CREATE THE DATABASE:
###disk_engine = create_engine('sqlite:///ticket_touting.db')

# %% [markdown]
# # Create a function!
#
# This function collects all artist information based on their genre. It then creates a column to specifiy wich genre they are, and then saves all artists into a single database.

# %%
def get_artist_by_genre(genre, per_page=5000):
    
    """Collect all artists the your genre of choice and save dataframe
    Then use data frame to store into database as a table

    Call URL for all electronic artists
    per_page = 5000 because it is the max"""
    
    # The genre must be lowercase so let's account for that
    genre = str.lower(genre)

    
    # string together url to call api
    # client_id is the api key
    # it then mashes together the api key with the desired genre and the number of results you want
    
    client_id='NDQxMDA3NXwxNDU5MDI4MzEx'
    get_artists_url = ('https://api.seatgeek.com/2/performers?format=json&client_id='+
                       client_id+'&genres.name='+genre+'&per_page='+str(per_page))
        
    
    # use url structure to call api key
    # then return json results into dataframe.
    # I am normalizing the 'performers' section of the json
    # because the other section is just meta data info. 
    # i.e. how many artists there are and other small info that 
    # can be derived from the infomatino in performers.
    
    r = requests.get(get_artists_url)
    json_all_artists = r.json()
    df_all_artists = json_normalize(json_all_artists)
    try: 
        all_artists_ids = json_normalize(df_all_artists['performers'][0])


        # once the json have been converted to a dataframe
        # I drop a couple of features: genres and taxonomies.
        # Both of the columns cause problems when we try to store them
        # into a SQL database. Both of the columns are not needed.
        # We know the genre already, so we will make a column to replace to droped 'genres.'
        # The taxonomies data does not seem to be useful. Almost all of them return the same thing.


        all_artists_ids = all_artists_ids.drop(['genres', 'taxonomies'], 1)
        # SeetGeek has a problem generating 'hip-hop' but it works
        # if you ping the api with hip or hop. Therefore, if either of those
        # are used then well save the genre column accordingly.
        if genre == 'hip' or genre == 'hop':
            all_artists_ids['genres'] = 'hip-hop'
        else:
            all_artists_ids['genres'] = genre

        # All of the columns that are strings are converted to them.
        # When the raw data is returned from the API it is not coming back
        # as a proper string, and therefore cannot be put into a SQL database.

        all_artists_ids[['divisions', 'has_upcoming_events', 'home_venue_id', 'id', 'image', 'images.huge',
                         'links', 'name', 'score', 'short_name', 'slug', 'stats.event_count', 
                         'type', 'url']] = all_artists_ids[['divisions', 'has_upcoming_events', 'home_venue_id',
                                                            'id', 'image', 'images.huge', 'links', 'name', 
                                                            'score', 'short_name', 'slug', 'stats.event_count',
                                                            'type', 'url']].astype('str')

        # Set the is as the index colum. All ids are (or should be) unique
        all_artists_ids = all_artists_ids.set_index('id')

        # Append the data collected to the artist database
        all_artists_ids.to_sql('all_artist_data_seetgeek', 'sqlite:///ticket_touting.db', if_exists='append', index=True, index_label='id')

        # Now That the data has been appended lets de-duplicate our table
        # To do this I am going to conncect to the data base:
        con = sqlite3.connect('ticket_touting.db')
        cur = con.cursor()

        # Then query the the artist table, only selecting distinc/unique instances
        query = "SELECT DISTINCT * FROM all_artist_data_seetgeek"
        cur.execute(query)

        # From there I will execute the query and save it as a dataframe with the
        # the appropriate columns
        column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                        'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

        # Once the 'fect' is executed with the correct columns I am going
        # to set the 'id' column as the index, and then push all of the
        # distinct/unique artist to the 'all_artists_data' table within
        # the 'ticket_touting' database

        pd.DataFrame(cur.fetchall(),
                     columns=column_names).set_index('id').to_sql('all_artist_data_seetgeek',
                                                                  'sqlite:///ticket_touting.db',
                                                                  if_exists='replace', index=True, index_label='id')
        return 'Finished adding {} artists!'.format(genre)
    
    except: 
        print '''This is an incorrect genre.
       \nYou should make sure that your genre does not have any spaces or special characters.'''

# %% [markdown]
# # Test
#
# Let's get data for just the electronic artist and see a snapshot of the stored data.

# %%
get_artist_by_genre('electronic')
# Out:
# 'Finished adding electronic artists!'

# %%
# Now That the data has been appended lets de-duplicate our table
# To do this I am going to conncect to the data base:

con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()

# Then query the the artist table, only selecting distinc/unique instances
query_test = "SELECT * FROM all_artist_data_seetgeek LIMIT 3"
cur.execute(query_test)

# From there I will execute the query and save it as a dataframe with the
# the appropriate columns
column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                    'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

# Once the 'fect' is executed with the correct columns I am going
# to set the 'id' column as the index.

pd.DataFrame(cur.fetchall(),
             columns=column_names).set_index('id')
# Out:
#       divisions has_upcoming_events home_venue_id  \
# id
# 7960        nan               False           nan
# 38619       nan                True           nan
# 25737       nan                True           nan
#
#                                                    image  \
# id
# 7960   https://chairnerd.global.ssl.fastly.net/images...
# 38619                                                nan
# 25737                                                nan
#
#                                              images.huge links  \
# id
# 7960   https://chairnerd.global.ssl.fastly.net/images...    []
# 38619                                                nan    []
# 25737                                                nan    []
#
#                       name     score           short_name  \
# id
# 7960   Swedish House Mafia  0.734832  Swedish House Mafia
# 38619               Sinden  0.691532               Sinden
# 25737      Trent Cantrelle  0.691532      Trent Cantrelle
#
#                       slug stats.event_count  type  \
# id
# 7960   swedish-house-mafia                 0  band
# 38619               sinden                 1  band
# 25737      trent-cantrelle                 1  band
#
#                                                     url      genres
# id
# 7960   https://seatgeek.com/swedish-house-mafia-tickets  electronic
# 38619               https://seatgeek.com/sinden-tickets  electronic
# 25737      https://seatgeek.com/trent-cantrelle-tickets  electronic

# %% [markdown]
# # Voilà! Let's get everything
#
# - Now that it worked lets collect all artist information and store it into a SQL database.
# - We will be able to use that data later to collect other data.
#     - I've noticed that SeatGeek's API has trouble return results if the genre has a space or special character in it. For that reason Rock will all be stored as one genre, and 'Hip' is short for hip-hop.

# %%
all_seetgeek_genres = ['Alternative', 'Rock', 'Country', 'Electronic', 'Hip',
                       'Indie', 'Pop', 'Rnb', 'Alternative', 'Blues', 'Classical',
                       'Folk', 'Jazz', 'Latin', 'Punk', 'Rap', 'Reggae', 'Soul']

# %%
for i in range(pd.DataFrame(all_seetgeek_genres).shape[0]):
    print all_seetgeek_genres[i]
    get_artist_by_genre(all_seetgeek_genres[i])
# Out:
# Alternative
# Rock
# Country
# Electronic
# Hip
# Indie
# Pop
# Rnb
# Alternative
# Blues
# Classical
# Folk
# Jazz
# Latin
# Punk
# Rap
# Reggae
# Soul

# %% [markdown]
# # Next up, more data!
# Now that I have collected all artist information I'm going to use that in order to collected data for all concerts for earch artist.

# %% [markdown]
# **I will use the genre names from the SQL artist table in order to search seetgeek's api.**

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query_test = "SELECT DISTINCT genres FROM all_artist_data_seetgeek"
cur.execute(query_test)
all_seetgeek_genres = pd.DataFrame(cur.fetchall(), columns=['genres'])
all_seetgeek_genres
# Out:
#          genres
# 0    electronic
# 1   alternative
# 2          rock
# 3       country
# 4       hip-hop
# 5         indie
# 6           pop
# 7           rnb
# 8         blues
# 9     classical
# 10         folk
# 11         jazz
# 12        latin
# 13         punk
# 14          rap
# 15       reggae
# 16         soul

# %% [markdown]
# **I'm using the distinct genres to search through the SQL table. The way that I will search and get results is shown in the code below. This code will be used in a function.**

# %%
query_test = "SELECT * FROM all_artist_data_seetgeek WHERE genres = '{}'".format(all_seetgeek_genres['genres'][0])
cur.execute(query_test)

# From there I will execute the query and save it as a dataframe with the
# the appropriate columns
column_names = ['id', 'divisions', 'has_upcoming_events', 'home_venue_id', 'image', 'images.huge', 'links', 'name',
                    'score', 'short_name', 'slug', 'stats.event_count', 'type', 'url', 'genres']

# Once the 'fect' is executed with the correct columns I am going
# to set the 'id' column as the index.

x = pd.DataFrame(cur.fetchall(),
             columns=column_names).set_index('id')

# %%
x
# Out:
#        divisions has_upcoming_events home_venue_id  \
# id
# 7960         nan               False           nan
# 38619        nan                True           nan
# 25737        nan                True           nan
# 18965        nan                True           nan
# 58199        nan               False           nan
# 22817        nan               False           nan
# 33619        nan                True           nan
# 17603        nan                True           nan
# 16783        nan                True           nan
# 34242        nan               False           nan
# 11721        nan               False           nan
# 22631        nan                True           nan
# 55540        nan               False           nan
# 22866        nan               False           nan
# 42876        nan                True           nan
# 22449        nan                True           nan
# 24940        nan                True           nan
# 85298        nan                True           nan
# 41374        nan                True           nan
# 22512        nan               False           nan
# 22617        nan                True           nan
# 24048        nan               False           nan
# 18124        nan                True           nan
# 22815        nan                True           nan
# 235786       nan               False           nan
# 23393        nan                True           nan
# 13665        nan               False           nan
# 22576        nan                True           nan
# 27139        nan                True           nan
# 32201        nan               False           nan
# ...          ...                 ...           ...
# 217457       nan               False           nan
# 239019       nan               False           nan
# 247593       nan                True           nan
# 283244       nan               False           nan
# 286159       nan               False           nan
# 286065       nan               False           nan
# 402616       nan               False           nan
# 442624       nan               False           nan
# 420024       nan               False           nan
# 450230       nan               False           nan
# 450204       nan               False           nan
# 450379       nan               False           nan
# 450386       nan               False           nan
# 450639       nan               False           nan
# 450709       nan               False           nan
# 450754       nan               False           nan
# 450691       nan               False           nan
# 450728       nan               False           nan
# 450778       nan               False           nan
# 450672       nan               False           nan
# 450526       nan               False           nan
# 450867       nan               False           nan
# 451271       nan               False           nan
# 450881       nan               False           nan
# 450879       nan               False           nan
# 451574       nan               False           nan
# 451625       nan               False           nan
# 49997        nan                True           nan
# 31350        nan                True           nan
# 23915        nan                True           nan
#
#                                                     image  \
# id
# 7960    https://chairnerd.global.ssl.fastly.net/images...
# 38619                                                 nan
# 25737                                                 nan
# 18965                                                 nan
# 58199   https://chairnerd.global.ssl.fastly.net/images...
# 22817                                                 nan
# 33619                                                 nan
# 17603   https://chairnerd.global.ssl.fastly.net/images...
# 16783                                                 nan
# 34242   https://chairnerd.global.ssl.fastly.net/images...
# 11721                                                 nan
# 22631                                                 nan
# 55540   https://chairnerd.global.ssl.fastly.net/images...
# 22866   https://chairnerd.global.ssl.fastly.net/images...
# 42876                                                 nan
# 22449   https://chairnerd.global.ssl.fastly.net/images...
# 24940   https://chairnerd.global.ssl.fastly.net/images...
# 85298                                                 nan
# 41374                                                 nan
# 22512                                                 nan
# 22617                                                 nan
# 24048   https://chairnerd.global.ssl.fastly.net/images...
# 18124                                                 nan
# 22815   https://chairnerd.global.ssl.fastly.net/images...
# 235786  https://chairnerd.global.ssl.fastly.net/images...
# 23393                                                 nan
# 13665   https://chairnerd.global.ssl.fastly.net/images...
# 22576                                                 nan
# 27139                                                 nan
# 32201   https://chairnerd.global.ssl.fastly.net/images...
# ...                                                   ...
# 217457                                                nan
# 239019                                                nan
# 247593                                                nan
# 283244                                                nan
# 286159                                                nan
# 286065                                                nan
# 402616                                                nan
# 442624                                                nan
# 420024                                                nan
# 450230                                                nan
# 450204                                                nan
# 450379                                                nan
# 450386                                                nan
# 450639                                                nan
# 450709                                                nan
# 450754                                                nan
# 450691                                                nan
# 450728                                                nan
# 450778                                                nan
# 450672                                                nan
# 450526                                                nan
# 450867                                                nan
# 451271                                                nan
# 450881                                                nan
# 450879                                                nan
# 451574                                                nan
# 451625                                                nan
# 49997                                                 nan
# 31350                                                 nan
# 23915                                                 nan
#
#                                               images.huge links  \
# id
# 7960    https://chairnerd.global.ssl.fastly.net/images...    []
# 38619                                                 nan    []
# 25737                                                 nan    []
# 18965                                                 nan    []
# 58199   https://chairnerd.global.ssl.fastly.net/images...    []
# 22817                                                 nan    []
# 33619                                                 nan    []
# 17603   https://chairnerd.global.ssl.fastly.net/images...    []
# 16783                                                 nan    []
# 34242   https://chairnerd.global.ssl.fastly.net/images...    []
# 11721                                                 nan    []
# 22631                                                 nan    []
# 55540   https://chairnerd.global.ssl.fastly.net/images...    []
# 22866   https://chairnerd.global.ssl.fastly.net/images...    []
# 42876                                                 nan    []
# 22449   https://chairnerd.global.ssl.fastly.net/images...    []
# 24940   https://chairnerd.global.ssl.fastly.net/images...    []
# 85298                                                 nan    []
# 41374                                                 nan    []
# 22512                                                 nan    []
# 22617                                                 nan    []
# 24048   https://chairnerd.global.ssl.fastly.net/images...    []
# 18124                                                 nan    []
# 22815   https://chairnerd.global.ssl.fastly.net/images...    []
# 235786  https://chairnerd.global.ssl.fastly.net/images...    []
# 450881                                            DJ Show       0.0
# 450879                                            FLT RSK       0.0
# 451574                                          Dian Diaz       0.0
# 451625                                     DJ Hazard - DJ       0.0
# 49997                                            Dmx Krew       0.0
# 31350                                           Sepalcure       0.0
# 23915                                               Kode9       0.0
#
#                                                short_name  \
# id
# 7960                                  Swedish House Mafia
# 38619                                              Sinden
# 25737                                     Trent Cantrelle
# 18965                                         Nina Kraviz
# 58199                                      Lady Starlight
# 22817                                           Huoratron
# 33619                                     Laurent Garnier
# 17603                                           Sensation
# 16783                                        Lee Burridge
# 34242                                           Zane Lowe
# 11721                                       Factory Floor
# 22631                                             Solomun
# 55540                                               MitiS
# 22866                                               Dixon
# 42876                               The Martinez Brothers
# 22449                                              Dub FX
# 24940                                           Icona Pop
# 85298                                      Flint Eastwood
# 41374                                                Tiga
# 22512                                       Tiger & Woods
# 22617                                          Guy Gerber
# 24048                                         The 2 Bears
# 18124                                               Scuba
# 22815                                       Birdy Nam Nam
# 235786                                               Arca
# 23393                                      Damian Lazarus
# 13665                                           The Knife
# 22576                                                AN21
# 27139                                              Kastle
# 32201                                                  UZ
# ...                                                   ...
# 217457                                          Pokerface
# 239019                                 Rabbit In The Moon
# 247593                                   Telefon Tel Aviv
# 283244                                              Ekkah
# 286159                                      Project Party
# 286065                                  DJ Scotty Thomson
# 402616              The Official Winter Social Afterparty
# 442624                                          DJ Espada
# 420024                                             Krimer
# 450230                                         Teen Flirt
# 450204  Hyperglow,  Howell New Jersey! America's Large...
# 450379                              Bass Nation: Doctor P
# 450386                                          Glow Land
# 450639                                        Mad Dubstep
# 450709                                       Cosmic Opera
# 450754                                        Hyphy Crunk
# 450691                                         Lucky 2012
# 450728                            Abstract Meets Rockhard
# 450778                                    Loud Mouth Bass
# 450672                                              Ton!c
# 450526                                             Quruli
# 450867                     Freakout! 8th Annual Halloween
# 451271                                          Hot Mix 5
# 450881                                            DJ Show
# 450879                                            FLT RSK
# 451574                                          Dian Diaz
# 451625                                     DJ Hazard - DJ
# 49997                                            Dmx Krew
# 31350                                           Sepalcure
# 23915                                               Kode9
#
#                                                      slug stats.event_count  \
# id
# 7960                                  swedish-house-mafia                 0
# 38619                                              sinden                 1
# 25737                                     trent-cantrelle                 1
# 18965                                         nina-kraviz                 2
# 58199                                      lady-starlight                 0
# 22817                                           huoratron                 0
# 33619                                     laurent-garnier                 1
# 17603                                           sensation                 4
# 16783                                        lee-burridge                 4
# 34242                                           zane-lowe                 0
# 11721                                       factory-floor                 0
# 22631                                             solomun                 1
# 55540                                               mitis                 0
# 22866                                               dixon                 0
# 42876                               the-martinez-brothers                 5
# 22449                                              dub-fx                 5
# 24940                                           icona-pop                 1
# 85298                                      flint-eastwood                 6
# 41374                                                tiga                 2
# 22512                                         tiger-woods                 0
# 22617                                          guy-gerber                 1
# 24048                                         the-2-bears                 0
# 18124                                               scuba                 2
# 22815                                       birdy-nam-nam                 1
# 235786                                               arca                 0
# 23393                                      damian-lazarus                 4
# 13665                                           the-knife                 0
# 22576                                                an21                 1
# 27139                                              kastle                 1
# 217457  band             https://seatgeek.com/pokerface-tickets  electronic
# 239019  band    https://seatgeek.com/rabbit-in-the-moon-tickets  electronic
# 247593  band      https://seatgeek.com/telefon-tel-aviv-tickets  electronic
# 283244  band                 https://seatgeek.com/ekkah-tickets  electronic
# 286159  band         https://seatgeek.com/project-party-tickets  electronic
# 286065  band     https://seatgeek.com/dj-scotty-thomson-tickets  electronic
# 402616  band  https://seatgeek.com/the-official-winter-socia...  electronic
# 442624  band             https://seatgeek.com/dj-espada-tickets  electronic
# 420024  band                https://seatgeek.com/krimer-tickets  electronic
# 450230  band            https://seatgeek.com/teen-flirt-tickets  electronic
# 450204  band  https://seatgeek.com/hyperglow-howell-new-jers...  electronic
# 450379  band  https://seatgeek.com/bass-nation-doctor-p-tickets  electronic
# 450386  band             https://seatgeek.com/glow-land-tickets  electronic
# 450639  band           https://seatgeek.com/mad-dubstep-tickets  electronic
# 450709  band          https://seatgeek.com/cosmic-opera-tickets  electronic
# 450754  band           https://seatgeek.com/hyphy-crunk-tickets  electronic
# 450691  band            https://seatgeek.com/lucky-2012-tickets  electronic
# 450728  band  https://seatgeek.com/abstract-meets-rockhard-t...  electronic
# 450778  band       https://seatgeek.com/loud-mouth-bass-tickets  electronic
# 450672  band                 https://seatgeek.com/ton-c-tickets  electronic
# 450526  band                https://seatgeek.com/quruli-tickets  electronic
# 450867  band  https://seatgeek.com/freakout-8th-annual-hallo...  electronic
# 451271  band             https://seatgeek.com/hot-mix-5-tickets  electronic
# 450881  band               https://seatgeek.com/dj-show-tickets  electronic
# 450879  band               https://seatgeek.com/flt-rsk-tickets  electronic
# 451574  band             https://seatgeek.com/dian-diaz-tickets  electronic
# 451625  band          https://seatgeek.com/dj-hazard-dj-tickets  electronic
# 49997   band              https://seatgeek.com/dmx-krew-tickets  electronic
# 31350   band             https://seatgeek.com/sepalcure-tickets  electronic
# 23915   band                 https://seatgeek.com/kode9-tickets  electronic
#
# [1806 rows x 14 columns]

# %% [markdown]
# **I'm making a function to do this data collection**

# %%
x.shape[0]
# Out:
# 1806

# %%
def get_concert_by_artist(genre_in_database):
    con = sqlite3.connect('ticket_touting.db')
    cur = con.cursor()
    query = "SELECT id, genres, short_name FROM all_artist_data_seetgeek WHERE genres = '{}'".format(genre_in_database)
    cur.execute(query)
    x = pd.DataFrame(cur.fetchall(),columns=['id', 'genres', 'short_name'])
    
    master_concerts = pd.DataFrame()
    
    for i in range(x.shape[0]):
        try:    
            artist_concert_info = "https://api.seatgeek.com/2/events?performers.id={}&client_id=NDQxMDA3NXwxNDU5MDI4MzEx&per_page=5000&datetime_utc.gt=2012-01-01".format(
                x['id'][i])

            r = requests.get(artist_concert_info)
            json_concert_per_artist = r.json()
            y = json_normalize(json_concert_per_artist)
            if y['events'][0] != []:
                single_artist_df = json_normalize(y['events'][0])
                single_artist_df['artist_name'] = x['short_name'][i]
                single_artist_df['artist_id'] = x['id'][i]
                single_artist_df['artist_genre'] = x['genres'][i]
                master_concerts = master_concerts.append(single_artist_df)
                


        except:
            'placeholder'
            
        if i % 50 == 0:
            print 'Searching #{} out of {}'.format(i, x.shape[0])
                

    # We will only put the data into a SQL database 
    # once all of the data has been collected.
    # Once the data is added to the database then we will run a 
    # distinct SQL function in order to de-duplicate the data

    print 'Making the database for {}'.format(genre_in_database)

    master_concerts = master_concerts.drop(['links', 'performers',
                                            'taxonomies', 'venue.links',
                                            'venue.url'], 1).set_index('id')
    master_concerts.to_sql('all_concert_data_seetgeek', 'sqlite:///ticket_touting.db',
                       if_exists='append', index=True, index_label='id')

    print 'Making the de-duplicated database!'

    # Now That the data has been appended lets de-duplicate our table
    # To do this I am going to conncect to the data base:
    con = sqlite3.connect('ticket_touting.db')
    cur = con.cursor()

    # Then query the the artist table, only selecting distinc/unique instances
    query = "SELECT DISTINCT * FROM all_concert_data_seetgeek"
    cur.execute(query)

    # From there I will execute the query and save it as a dataframe with the
    # the appropriate columns
    column_names = ['id', 'announce_date', 'created_at', 'date_tbd', 'datetime_local', 'datetime_tbd',
                    'datetime_utc', 'general_admission', 'score','short_title','stats.average_price',
                     'stats.highest_price','stats.listing_count','stats.lowest_price', 
                    'stats.lowest_price_good_deals','time_tbd','title','type','url','venue.address',
                    'venue.city','venue.country','venue.display_location','venue.extended_address',
                    'venue.id','venue.location.lat','venue.location.lon','venue.name',
                    'venue.postal_code','venue.score','venue.slug', 'venue.state', 
                    'venue.timezone','visible_until_utc','artist_name','artist_id','artist_genre']



    # Once the 'fect' is executed with the correct columns I am going
    # to set the 'id' column as the index, and then push all of the
    # distinct/unique artist to the 'all_artists_data' table within
    # the 'ticket_touting' database

    pd.DataFrame(cur.fetchall(),
                 columns=column_names).set_index('id').to_sql('all_concert_data_seetgeek',
                                                              'sqlite:///ticket_touting.db',
                                                              if_exists='replace', index=True, index_label='id')

    return 'Done!'

# %%
get_concert_by_artist('electronic')
# Out:
# Searching #0 out of 1806
# Searching #50 out of 1806
# Searching #100 out of 1806
# Searching #150 out of 1806
# Searching #200 out of 1806
# Searching #250 out of 1806
# Searching #300 out of 1806
# Searching #350 out of 1806
# Searching #400 out of 1806
# Searching #450 out of 1806
# Searching #500 out of 1806
# Searching #550 out of 1806
# Searching #600 out of 1806
# Searching #650 out of 1806
# Searching #700 out of 1806
# Searching #750 out of 1806
# Searching #800 out of 1806
# Searching #850 out of 1806
# Searching #900 out of 1806
# Searching #950 out of 1806
# Searching #1000 out of 1806
# Searching #1050 out of 1806
# Searching #1100 out of 1806
# Searching #1150 out of 1806
# Searching #1200 out of 1806
# Searching #1250 out of 1806
# Searching #1300 out of 1806
# Searching #1350 out of 1806
# Searching #1400 out of 1806
# Searching #1450 out of 1806
# Searching #1500 out of 1806
# Searching #1550 out of 1806
# Searching #1600 out of 1806
# Searching #1650 out of 1806
# Searching #1700 out of 1806
# Searching #1750 out of 1806
# Searching #1800 out of 1806
# Making the database for electronic
# Making the de-duplicated database!
# 'Done!'

# %% [markdown]
# Let's do a query and make sure the data stored properly

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
# 3249946                                     Art Department
# 3124892  Osheaga Festival (3 Day Pass) with Lucius, Ban...
# 3248091                                          Cut Snake
# 3252001                                         Leo Kalyan
# 3095084  Sonic Bloom Music Festival (4 Day Pass) with E...
# 3266140                                         Rinocerose
# 3235417                                   Telefon Tel Aviv
# 3038537                      Moderat with Telefon Tel Aviv
# 3038504                      Moderat with Telefon Tel Aviv
# 3038381                      Moderat with Telefon Tel Aviv
# 3262450                                   Telefon Tel Aviv
# 3264749                      Dmx Krew with Matthew Herbert
# 3252660                             Sepalcure with Beshken
# 3233696                                              Kode9
# 3264537                                  Kode9 with 6blocc
# 3245727                  Kode9 with Liquid Courage Karaoke
#
#          stats.average_price     ...                          venue.name  \
# id                               ...
# 2948301                  NaN     ...               Stade Charles Ehrmann
# 2955353                  NaN     ...       Estadi Olimpic Lluis Companys
# 2951454                  NaN     ...       Estadi Olimpic Lluis Companys
# 2948351                  NaN     ...                       Veltins Arena
# 2939818                  NaN     ...          City of Manchester Stadium
# 2947368                314.0     ...                      Etihad Stadium
# 2943448                  NaN     ...       Hampden Park National Stadium
# 2948330                  NaN     ...                  Letzigrund Stadion
# 3219699                  NaN     ...                  Letzigrund Stadion
# 2948974                  NaN     ...                  Letzigrund Stadion
# 2960342                  NaN     ...                     Wembley Stadium
# 3025386                  NaN     ...                     Wembley Stadium
# 2939963                502.0     ...                     Wembley Stadium
# 2939962                532.0     ...                     Wembley Stadium
# 2947460                278.0     ...                     Wembley Stadium
# 2944252                  NaN     ...                     Amsterdam Arena
# 2950894                  NaN     ...                     Amsterdam Arena
# 2944332                  NaN     ...               Olympiastadion Berlin
# 2948352                  NaN     ...                    Volksparkstadion
# 2960459                  NaN     ...                       Friends Arena
# 2973861                  NaN     ...                        Telia Parken
# 2973806                  NaN     ...                        Telia Parken
# 3067939                317.5     ...                     MetLife Stadium
# 3078109                305.0     ...                     MetLife Stadium
# 3211899                179.0     ...                    Scottrade Center
# 3067931                350.0     ...                       Soldier Field
# 3078108                241.0     ...                       Soldier Field
# 3211429                238.0     ...                     KFC Yum! Center
# 3211876                257.0     ...                    Nationwide Arena
# 3068289                247.0     ...                    Gillette Stadium
# ...                      ...     ...                                 ...
# 3100379                  NaN     ...                         Space Ibiza
# 3100378                  NaN     ...                         Space Ibiza
# 3247855                 36.0     ...                Space Ibiza New York
# 3244514                  NaN     ...                       Windmill Cove
# 3209732                 37.0     ...                        First Avenue
# 3226340                  NaN     ...                   Ibiza Rocks Hotel
# 3186012                  NaN     ...              House of Blues Orlando
# 3219950                  NaN     ...       Alix Goolden Performance Hall
# 3259645                  NaN     ...                        Public Works
# 3140863                  NaN     ...                         La Terrazza
# 3204263                  NaN     ...                  The Regent Theater
# 3244514                  NaN     ...                       Windmill Cove
# 3228742                  NaN     ...                   Blue Marlin Dubai
# 3023370                  NaN     ...                           Barcelona
# 3249946                 25.0     ...                        New City Gas
# 3124892                465.0     ...                   Parc Jean-Drapeau
# 3248091                  NaN     ...                           El Camino
# 3252001                  NaN     ...                  The Pickle Factory
# 3095084                260.0     ...                   Hummingbird Ranch
# 3266140                  NaN     ...                          Water Rats
# 3235417                  NaN     ...                    Knitting Factory
# 3038537                 72.0     ...                       Vogue Theatre
# 3038504                 68.0     ...                         The Showbox
# 3038381                 82.0     ...                       Fonda Theatre
# 3262450                  NaN     ...                          The Parish
# 3264749                  NaN     ...                            The Loft
# 3252660                  NaN     ...                            Echoplex
# 3233696                  NaN     ...                         Trans-Pecos
# 3264537                  NaN     ...                     Union Nightclub
# 3245727                  NaN     ...                       The Crocodile
#
#         venue.postal_code  venue.score                     venue.slug  \
# id
# 2948301            6000.0     0.000000          stade-charles-ehrmann
# 2955353            8038.0     0.000000  estadi-olimpic-lluis-companys
# 2951454            8038.0     0.000000  estadi-olimpic-lluis-companys
# 2948351           45891.0     0.000000                  veltins-arena
# 2939818           M11 3FF     0.000000     city-of-manchester-stadium
# 2947368           M11 3FF     0.751505               etihad-stadium-2
# 2943448           G42 9BA     0.731718  hampden-park-national-stadium
# 2948330            8004.0     0.316511             letzigrund-stadion
# 3219699            8004.0     0.316511             letzigrund-stadion
# 2948974            8004.0     0.316511             letzigrund-stadion
# 2960342           HA9 0WS     0.829759                wembley-stadium
# 3025386           HA9 0WS     0.829759                wembley-stadium
# 2939963           HA9 0WS     0.829759                wembley-stadium
# 2939962           HA9 0WS     0.829759                wembley-stadium
# 2947460           HA9 0WS     0.829759                wembley-stadium
# 2944252           1101 AX     0.432544                amsterdam-arena
# 2950894           1101 AX     0.432544                amsterdam-arena
# 2944332           14053.0     0.811830          olympiastadion-berlin
# 2948352                       0.000000               volksparkstadion
# 2960459           16956.0     0.000000                  friends-arena
# 2973861                       0.000000                   telia-parken
# 2973806                       0.000000                   telia-parken
# 3067939            7073.0     0.961551                metlife-stadium
# 3078109            7073.0     0.961551                metlife-stadium
# 3211899           63103.0     0.794522               scottrade-center
# 3067931           60605.0     0.955779                  soldier-field
# 3078108           60605.0     0.955779                  soldier-field
# 3211429           40202.0     0.761433                 kfc-yum-center
# 3211876           43215.0     0.741552               nationwide-arena
# 3068289            2035.0     0.904805               gillette-stadium
# ...                   ...          ...                            ...
# 3100379             07817     0.000000                    space-ibiza
# 3100378             07817     0.000000                    space-ibiza
# 3247855             10019     0.440001           space-ibiza-new-york
# 3244514             95206     0.000000                  windmill-cove
# 3209732             55403     0.536802                   first-avenue
# 3226340             07820     0.000000            ibiza-rocks-hotel-1
# 3186012             32830     0.544915         house-of-blues-orlando
# 3219950           V8V 3P4     0.359898  alix-goolden-performance-hall
# 3259645             94103     0.492428                   public-works
# 3140863                       0.000000                  la-terrazza-3
# 3204263             90013     0.534449             the-regent-theater
# 3244514             95206     0.000000                  windmill-cove
# 3228742            136051     0.000000              blue-marlin-dubai
# 3023370             08014     0.000000                    barcelona-9
# 3249946           H3C 1S4     0.536073                   new-city-gas
# 3124892           H3C 1A9     0.655348              parc-jean-drapeau
# 3248091             92101     0.000000                    el-camino-1
# 3252001            E2 9DU     0.000000             the-pickle-factory
# 3095084             81069     0.542572              hummingbird-ranch
# 3266140          WC1X 8BZ     0.000000                     water-rats
# 3235417     Telefon Tel Aviv    247593   electronic
# 3038537     Telefon Tel Aviv    247593   electronic
# 3038504     Telefon Tel Aviv    247593   electronic
# 3038381     Telefon Tel Aviv    247593   electronic
# 3262450     Telefon Tel Aviv    247593   electronic
# 3264749             Dmx Krew     49997   electronic
# 3252660            Sepalcure     31350   electronic
# 3233696                Kode9     23915   electronic
# 3264537                Kode9     23915   electronic
# 3245727                Kode9     23915   electronic
#
# [125903 rows x 36 columns]

# %% [markdown]
# # Collect All Data
#
# Now I am going to collect concert data for all genres.

# %%
for i in range(all_seetgeek_genres.shape[0]):
    print all_seetgeek_genres['genres'][i]
    get_concert_by_artist(all_seetgeek_genres['genres'][i])
# Out:
# skip! edm already done!
# alternative
# Searching #0 out of 5000
# Searching #50 out of 5000
# Searching #100 out of 5000
# Searching #150 out of 5000
# Searching #200 out of 5000
# Searching #250 out of 5000
# Searching #300 out of 5000
# Searching #350 out of 5000
# Searching #400 out of 5000
# Searching #450 out of 5000
# Searching #500 out of 5000
# Searching #550 out of 5000
# Searching #600 out of 5000
# Searching #650 out of 5000
# Searching #700 out of 5000
# Searching #750 out of 5000
# Searching #800 out of 5000
# Searching #850 out of 5000
# Searching #900 out of 5000
# Searching #950 out of 5000
# Searching #1000 out of 5000
# Searching #1050 out of 5000
# Searching #1100 out of 5000
# Searching #1150 out of 5000
# Searching #1200 out of 5000
# Searching #1250 out of 5000
# Searching #1300 out of 5000
# Searching #1350 out of 5000
# Searching #1400 out of 5000
# Searching #1450 out of 5000
# Searching #1500 out of 5000
# Searching #1550 out of 5000
# Searching #1600 out of 5000
# Searching #1650 out of 5000
# Searching #1700 out of 5000
# Searching #1750 out of 5000
# Searching #1800 out of 5000
# Searching #1850 out of 5000
# Searching #1900 out of 5000
# Searching #1950 out of 5000
# Searching #2000 out of 5000
# Searching #2050 out of 5000
# Searching #2100 out of 5000
# Searching #2150 out of 5000
# Searching #2200 out of 5000
# Searching #2250 out of 5000
# Searching #2300 out of 5000
# Searching #2350 out of 5000
# Searching #2400 out of 5000
# Searching #2450 out of 5000
# Searching #2500 out of 5000
# Searching #2550 out of 5000
# Searching #2600 out of 5000
# Searching #2650 out of 5000
# Searching #2700 out of 5000
# Searching #2750 out of 5000
# Searching #2800 out of 5000
# Searching #2850 out of 5000
# Searching #2900 out of 5000
# Searching #2950 out of 5000
# Searching #3000 out of 5000
# Searching #3050 out of 5000
# Searching #3100 out of 5000
# Searching #3150 out of 5000
# Searching #3200 out of 5000
# Searching #3250 out of 5000
# Searching #3300 out of 5000
# Searching #3350 out of 5000
# Searching #3400 out of 5000
# Searching #3450 out of 5000
# Searching #3500 out of 5000
# Searching #3550 out of 5000
# Searching #3600 out of 5000
# Searching #3650 out of 5000
# Searching #3700 out of 5000
# Searching #3750 out of 5000
# Searching #3800 out of 5000
# Searching #3850 out of 5000
# Searching #3900 out of 5000
# Searching #3950 out of 5000
# Searching #4000 out of 5000
# Searching #4050 out of 5000
# Searching #4100 out of 5000
# Searching #4150 out of 5000
# Searching #4200 out of 5000
# Searching #4250 out of 5000
# Searching #4300 out of 5000
# Searching #4350 out of 5000
# Searching #4400 out of 5000
# Searching #4450 out of 5000
# Searching #4500 out of 5000
# Searching #4550 out of 5000
# Searching #4600 out of 5000
# Searching #4650 out of 5000
# Searching #4700 out of 5000
# Searching #4750 out of 5000
# Searching #4800 out of 5000
# Searching #4850 out of 5000
# Searching #4900 out of 5000
# Searching #4950 out of 5000
# Making the database for alternative
# Making the de-duplicated database!
# rock
# Searching #0 out of 5000
# Searching #50 out of 5000
# Searching #100 out of 5000
# Searching #150 out of 5000
# Searching #200 out of 5000
# Searching #250 out of 5000
# Searching #300 out of 5000
# Searching #350 out of 5000
# Searching #400 out of 5000
# Searching #450 out of 5000
# Searching #500 out of 5000
# Searching #550 out of 5000
# Searching #600 out of 5000
# Searching #650 out of 5000
# Searching #700 out of 5000
# Searching #750 out of 5000
# Searching #800 out of 5000
# Searching #850 out of 5000
# Searching #900 out of 5000
# Searching #950 out of 5000
# Searching #1000 out of 5000
# Searching #1050 out of 5000
# Searching #1100 out of 5000
# Searching #1150 out of 5000
# Searching #1200 out of 5000
# Searching #1250 out of 5000
# Searching #1300 out of 5000
# Searching #1350 out of 5000
# Searching #1400 out of 5000
# Searching #1450 out of 5000
# Searching #1500 out of 5000
# Searching #1550 out of 5000
# Searching #1600 out of 5000
# Searching #1650 out of 5000
# Searching #1700 out of 5000
# Searching #1750 out of 5000
# Searching #1800 out of 5000
# Searching #1850 out of 5000
# Searching #1900 out of 5000
# Searching #1950 out of 5000
# Searching #2000 out of 5000
# Searching #2050 out of 5000
# Searching #2100 out of 5000
# Searching #2150 out of 5000
# Searching #2200 out of 5000
# Searching #2250 out of 5000
# Searching #2300 out of 5000
# Searching #2350 out of 5000
# Searching #2400 out of 5000
# Searching #2450 out of 5000
# Searching #2500 out of 5000
# Searching #2550 out of 5000
# Searching #2600 out of 5000
# Searching #2650 out of 5000
# Searching #2700 out of 5000
# Searching #2750 out of 5000
# Searching #2800 out of 5000
# Searching #2850 out of 5000
# Searching #2900 out of 5000
# Searching #2950 out of 5000
# Searching #3000 out of 5000
# Searching #3050 out of 5000
# Searching #3100 out of 5000
# Searching #3150 out of 5000
# Searching #3200 out of 5000
# Searching #3250 out of 5000
# Searching #3300 out of 5000
# Searching #3350 out of 5000
# Searching #3400 out of 5000
# Searching #3450 out of 5000
# Searching #3500 out of 5000
# Searching #3550 out of 5000
# Searching #3600 out of 5000
# Searching #3650 out of 5000
# Searching #3700 out of 5000
# Searching #3750 out of 5000
# Searching #3800 out of 5000
# Searching #3850 out of 5000
# Searching #3900 out of 5000
# Searching #3950 out of 5000
# Searching #4000 out of 5000
# Searching #4050 out of 5000
# Searching #4100 out of 5000
# Searching #4150 out of 5000
# Searching #4200 out of 5000
# Searching #4250 out of 5000
# Searching #4300 out of 5000
# Searching #4350 out of 5000
# Searching #4400 out of 5000
# Searching #4450 out of 5000
# Searching #4500 out of 5000
# Searching #4550 out of 5000
# Searching #4600 out of 5000
# Searching #4650 out of 5000
# Searching #4700 out of 5000
# Searching #550 out of 589
# Making the database for indie
# Making the de-duplicated database!
# pop
# Searching #0 out of 5000
# Searching #50 out of 5000
# Searching #100 out of 5000
# Searching #150 out of 5000
# Searching #200 out of 5000
# Searching #250 out of 5000
# Searching #300 out of 5000
# Searching #350 out of 5000
# Searching #400 out of 5000
# Searching #450 out of 5000
# Searching #500 out of 5000
# Searching #550 out of 5000
# Searching #600 out of 5000
# Searching #650 out of 5000
# Searching #700 out of 5000
# Searching #750 out of 5000
# Searching #800 out of 5000
# Searching #850 out of 5000
# Searching #900 out of 5000
# Searching #950 out of 5000
# Searching #1000 out of 5000
# Searching #1050 out of 5000
# Searching #1100 out of 5000
# Searching #1150 out of 5000
# Searching #1200 out of 5000
# Searching #1250 out of 5000
# Searching #1300 out of 5000
# Searching #1350 out of 5000
# Searching #1400 out of 5000
# Searching #1450 out of 5000
# Searching #1500 out of 5000
# Searching #1550 out of 5000
# Searching #1600 out of 5000
# Searching #1650 out of 5000
# Searching #1700 out of 5000
# Searching #1750 out of 5000
# Searching #1800 out of 5000
# Searching #1850 out of 5000
# Searching #1900 out of 5000
# Searching #1950 out of 5000
# Searching #2000 out of 5000
# Searching #2050 out of 5000
# Searching #2100 out of 5000
# Searching #2150 out of 5000
# Searching #2200 out of 5000
# Searching #2250 out of 5000
# Searching #2300 out of 5000
# Searching #2350 out of 5000
# Searching #2400 out of 5000
# Searching #2450 out of 5000
# Searching #2500 out of 5000
# Searching #2550 out of 5000
# Searching #2600 out of 5000
# Searching #2650 out of 5000
# Searching #2700 out of 5000
# Searching #2750 out of 5000
# Searching #2800 out of 5000
# Searching #2850 out of 5000
# Searching #2900 out of 5000
# Searching #2950 out of 5000
# Searching #3000 out of 5000
# Searching #3050 out of 5000
# Searching #3100 out of 5000
# Searching #3150 out of 5000
# Searching #3200 out of 5000
# Searching #3250 out of 5000
# Searching #3300 out of 5000
# Searching #3350 out of 5000
# Searching #3400 out of 5000
# Searching #3450 out of 5000
# Searching #3500 out of 5000
# Searching #3550 out of 5000
# Searching #3600 out of 5000
# Searching #3650 out of 5000
# Searching #3700 out of 5000
# Searching #3750 out of 5000
# Searching #3800 out of 5000
# Searching #3850 out of 5000
# Searching #3900 out of 5000
# Searching #3950 out of 5000
# Searching #4000 out of 5000
# Searching #4050 out of 5000
# Searching #4100 out of 5000
# Searching #4150 out of 5000
# Searching #4200 out of 5000
# Searching #4250 out of 5000
# Searching #4300 out of 5000
# Searching #4350 out of 5000
# Searching #4400 out of 5000
# Searching #4450 out of 5000
# Searching #4500 out of 5000
# Searching #4550 out of 5000
# Searching #4600 out of 5000
# Searching #4650 out of 5000
# Searching #4700 out of 5000
# Searching #4750 out of 5000
# Searching #4800 out of 5000
# Searching #4850 out of 5000
# Searching #4900 out of 5000
# Searching #4950 out of 5000
# Making the database for pop
# Making the de-duplicated database!
# rnb
# Searching #0 out of 957
# Searching #50 out of 957
# Searching #100 out of 957
# Searching #150 out of 957
# Searching #200 out of 957
# Searching #250 out of 957
# Searching #300 out of 957
# Searching #350 out of 957
# Searching #400 out of 957
# Searching #400 out of 1695
# Searching #450 out of 1695
# Searching #500 out of 1695
# Searching #550 out of 1695
# Searching #600 out of 1695
# Searching #650 out of 1695
# Searching #700 out of 1695
# Searching #750 out of 1695
# Searching #800 out of 1695
# Searching #850 out of 1695
# Searching #900 out of 1695
# Searching #950 out of 1695
# Searching #1000 out of 1695
# Searching #1050 out of 1695
# Searching #1100 out of 1695
# Searching #1150 out of 1695
# Searching #1200 out of 1695
# Searching #1250 out of 1695
# Searching #1300 out of 1695
# Searching #1350 out of 1695
# Searching #1400 out of 1695
# Searching #1450 out of 1695
# Searching #1500 out of 1695
# Searching #1550 out of 1695
# Searching #1600 out of 1695
# Searching #1650 out of 1695
# Making the database for rap
# Making the de-duplicated database!
# reggae
# Searching #0 out of 416
# Searching #50 out of 416
# Searching #100 out of 416
# Searching #150 out of 416
# Searching #200 out of 416
# Searching #250 out of 416
# Searching #300 out of 416
# Searching #350 out of 416
# Searching #400 out of 416
# Making the database for reggae
# Making the de-duplicated database!
# soul
# Searching #0 out of 1226
# Searching #50 out of 1226
# Searching #100 out of 1226
# Searching #150 out of 1226
# Searching #200 out of 1226
# Searching #250 out of 1226
# Searching #300 out of 1226
# Searching #350 out of 1226
# Searching #400 out of 1226
# Searching #450 out of 1226
# Searching #500 out of 1226
# Searching #550 out of 1226
# Searching #600 out of 1226
# Searching #650 out of 1226
# Searching #700 out of 1226
# Searching #750 out of 1226
# Searching #800 out of 1226
# Searching #850 out of 1226
# Searching #900 out of 1226
# Searching #950 out of 1226
# Searching #1000 out of 1226
# Searching #1050 out of 1226
# Searching #1100 out of 1226
# Searching #1150 out of 1226
# Searching #1200 out of 1226
# Making the database for soul
# Making the de-duplicated database!

# %% [markdown]
# **I'm going to execute a couple of queries to make sure that the data is stored ok. First I will do a simple query a head of the dataframe. Then I'm going to ask for all of the unique genres within the table.**

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query = "SELECT * FROM all_concert_data_seetgeek limit 10"
cur.execute(query)

column_names = ['id', 'announce_date', 'created_at', 'date_tbd', 'datetime_local', 'datetime_tbd',
                'datetime_utc', 'general_admission', 'score','short_title','stats.average_price',
                 'stats.highest_price','stats.listing_count','stats.lowest_price', 
                'stats.lowest_price_good_deals','time_tbd','title','type','url','venue.address',
                'venue.city','venue.country','venue.display_location','venue.extended_address',
                'venue.id','venue.location.lat','venue.location.lon','venue.name',
                'venue.postal_code','venue.score','venue.slug', 'venue.state', 
                'venue.timezone','visible_until_utc','artist_name','artist_id','artist_genre']

pd.DataFrame(cur.fetchall(), columns=column_names).set_index('id')
# Out:
#                announce_date           created_at date_tbd  \
# id
# 2948301  2015-11-30T00:00:00  2015-11-30T00:00:00        0
# 2955353  2015-12-05T00:00:00  2015-12-05T00:00:00        0
# 2951454  2015-12-03T00:00:00  2015-12-03T00:00:00        0
# 2948351  2015-11-30T00:00:00  2015-11-30T00:00:00        0
# 2939818  2015-11-22T00:00:00  2015-11-22T00:00:00        0
# 2947368  2015-11-28T00:00:00  2015-11-28T00:00:00        0
# 2943448  2015-11-25T00:00:00  2015-11-25T00:00:00        0
# 2955353                  None  Europe/Madrid  2016-05-26T23:00:00    Coldplay
# 2951454                  None  Europe/Madrid  2016-05-27T21:00:00    Coldplay
# 2948351  North Rhine-westphal  Europe/Berlin  2016-06-01T20:00:00    Coldplay
# 2939818                   Man  Europe/London  2016-06-04T19:00:00    Coldplay
# 2947368            Lancashire  Europe/London  2016-06-05T19:00:00    Coldplay
# 2943448          Glasgow City  Europe/London  2016-06-07T19:00:00    Coldplay
# 2948330                    ZH  Europe/Zurich  2016-06-11T21:00:00    Coldplay
# 3219699                    ZH  Europe/Zurich  2016-06-12T19:30:00    Coldplay
# 2948974                    ZH  Europe/Zurich  2016-06-12T21:00:00    Coldplay
#
#         artist_id artist_genre
# id
# 2948301        32  alternative
# 2955353        32  alternative
# 2951454        32  alternative
# 2948351        32  alternative
# 2939818        32  alternative
# 2947368        32  alternative
# 2943448        32  alternative
# 2948330        32  alternative
# 3219699        32  alternative
# 2948974        32  alternative
#
# [10 rows x 36 columns]

# %%
con = sqlite3.connect('ticket_touting.db')
cur = con.cursor()
query = "SELECT DISTINCT artist_genre FROM all_concert_data_seetgeek"
cur.execute(query)

column_names = ['artist_genre']

pd.DataFrame(cur.fetchall(), columns=column_names)
# Out:
#              artist_genre
# 0     2016-05-15T02:00:00
# 1     2016-05-28T09:00:00
# 2     2016-05-30T03:00:00
# 3     2016-05-31T07:00:00
# 4     2016-05-08T00:00:00
# 5     2016-05-08T05:00:00
# 6     2016-05-19T07:00:00
# 7     2016-06-18T21:00:00
# 8     2016-07-02T23:00:00
# 9     2016-05-22T00:00:00
# 10    2016-05-30T07:00:00
# 11    2016-06-05T22:00:00
# 12    2016-06-17T14:00:00
# 13    2016-05-07T00:00:00
# 14    2016-05-13T09:00:00
# 15    2016-05-14T09:00:00
# 16    2016-05-15T04:00:00
# 17    2016-05-23T22:00:00
# 18    2016-05-29T13:30:00
# 19    2016-06-25T03:00:00
# 20    2016-06-26T03:00:00
# 21    2016-06-27T08:00:00
# 22    2016-07-15T04:00:00
# 23    2016-07-29T22:00:00
# 24    2016-06-19T03:00:00
# 25    2016-05-15T05:00:00
# 26    2016-05-16T04:00:00
# 27    2016-05-26T06:00:00
# 28    2016-05-27T06:00:00
# 29    2016-05-30T04:00:00
# ...                   ...
# 1321  2016-05-11T04:30:00
# 1322  2016-05-12T04:30:00
# 1323  2016-05-16T02:30:00
# 1324  2016-05-20T03:30:00
# 1325  2016-05-08T17:00:00
# 1326  2016-06-02T23:00:00
# 1327  2016-07-28T00:00:00
# 1328  2016-09-23T22:00:00
# 1329  2016-06-18T08:30:00
# 1330  2016-05-06T19:00:00
# 1331  2016-05-08T21:00:00
# 1332  2016-07-26T22:30:00
# 1333  2016-05-16T22:30:00
# 1334  2016-05-20T07:30:00
# 1335          alternative
# 1336                 rock
# 1337              country
# 1338              hip-hop
# 1339                indie
# 1340                  pop
# 1341                  rnb
# 1342                blues
# 1343            classical
# 1344                 folk
# 1345                 jazz
# 1346                latin
# 1347                 punk
# 1348                  rap
# 1349               reggae
# 1350                 soul
#
# [1351 rows x 1 columns]
