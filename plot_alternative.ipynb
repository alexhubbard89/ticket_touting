# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('seatgeek_alternative_data_concerts.csv')

# %%
df.head(3)
# Out:
#          announce_date artist_name           created_at date_tbd  \
# 0  2015-11-28T00:00:00    Coldplay  2015-11-28T00:00:00    False
# 1  2015-11-22T00:00:00    Coldplay  2015-11-22T00:00:00    False
# 2  2015-11-22T00:00:00    Coldplay  2015-11-22T00:00:00    False
#
#         datetime_local datetime_tbd         datetime_utc general_admission  \
# 0  2016-06-05T16:00:00        False  2016-06-05T15:00:00               NaN
# 1  2016-06-16T16:00:00        False  2016-06-16T15:00:00               NaN
# 2  2016-06-18T16:00:00        False  2016-06-18T15:00:00               NaN
#
#         id links         ...          venue.location.lat  venue.location.lon  \
# 0  2947368    []         ...                     53.4829           -2.204470
# 1  2939963    []         ...                     51.5560           -0.279519
# 2  2939962    []         ...                     51.5560           -0.279519
#
#         venue.name  venue.postal_code  venue.score        venue.slug  \
# ...

# %%
df['concert_score'] = df['score']*df['venue.score']

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['venue.score'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['venue.score'],
          c='g', label='Chicago', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['venue.score'],
          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('Venue Score')
plt.show();
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['stats.highest_price'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['stats.highest_price'],
          c='g', label='Chicago', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['stats.highest_price'],
          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.ylim(0, 20000)
plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('stats.highest_price')
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['venue.score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['stats.highest_price'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['venue.score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['stats.highest_price'],
          c='g', label='Chicago', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['venue.score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['stats.highest_price'],
          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.title("Venue Score by Artist Score")
plt.xlabel('venue.score')
plt.ylabel('stats.highest_price')
plt.ylim(0,20000)
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['stats.average_price'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['stats.average_price'],
          c='g', label='Chicago', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['stats.average_price'],
          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('average_price')
plt.ylim(0,400)
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)


ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['stats.lowest_price'],
          c='r', label='New York', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['stats.lowest_price'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['stats.lowest_price'],
          c='g', label='Chicago', s=40)


plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('stats.lowest_price')
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['score'], 
           y=df[(df['artist_name'] == 'Coldplay')]['stats.highest_price'],
          c='b', label='data', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='g', label='Chicago', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))

plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('stats.highest_price')
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['venue.score'], 
           y=df[(df['artist_name'] == 'Coldplay')]['stats.highest_price'],
          c='b', label='data', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='g', label='Chicago', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))

plt.title("Venue Score by Artist Score")
plt.xlabel('venue.score')
plt.ylabel('stats.highest_price')
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[df['venue.timezone'] ==  'America/Los_Angeles']['concert_score'], 
           y=df[df['venue.timezone'] ==  'America/Los_Angeles']['stats.highest_price'],
          c='b', label='LA', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/Chicago']['concert_score'], 
           y=df[df['venue.timezone'] ==  'America/Chicago']['stats.highest_price'],
          c='g', label='Chicago', s=40)

ax.scatter(x=df[df['venue.timezone'] ==  'America/New_York']['concert_score'], 
           y=df[df['venue.timezone'] ==  'America/New_York']['stats.highest_price'],
          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))
plt.title("Venue Score by Artist Score")
plt.xlabel('Artist Score')
plt.ylabel('Venue Score')
plt.show();

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['concert_score'], 
           y=df[(df['artist_name'] == 'Coldplay')]['stats.highest_price'],
          c='b', label='data', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='g', label='Chicago', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))

plt.title("Venue Score by Artist Score")
plt.xlabel('venue.artist')
plt.ylabel('stats.highest_price')
plt.show();

# %%
from sklearn.preprocessing import StandardScaler

# %%
stdsc = StandardScaler()

# %%
from sklearn.preprocessing import scale

# %%
df['stats.highest_price_stdsc'] = scale(df['stats.highest_price'].astype(float))

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['concert_score'], 
           y=df[(df['artist_name'] == 'Coldplay')]['stats.highest_price_stdsc'],
          c='b', label='data', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='g', label='Chicago', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))

plt.title("Venue Score by Artist Score")
plt.xlabel('venue.artist')
plt.ylabel('stats.highest_price')
plt.show();

# %%
df['score_scale'] = df['concert_score'] + df['stats.highest_price_stdsc']

# %%
df['datetime_local'] = pd.to_datetime(df['datetime_local'])

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['datetime_local'], 
           y=df[(df['artist_name'] == 'Coldplay')]['score_scale'],
          c='b', label='data', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/Chicago') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='g', label='Chicago', s=40)

#ax.scatter(x=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['score'], 
#           y=df[(df['venue.timezone'] ==  'America/New_York') & 
#                  (df['artist_name'] == 'Coldplay')]['stats.highest_price'],
#          c='r', label='New York', s=40)

plt.legend(loc='upper right')
plt.legend(bbox_to_anchor=(1.2, 1))

plt.title("Venue Score by Artist Score")
plt.xlabel('datetime_local')
plt.ylabel('score_scale')
plt.show();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-75682a7baddb> in <module>()
#       3 ax.scatter(x=df[ (df['artist_name'] == 'Coldplay')]['datetime_local'],
#       4            y=df[(df['artist_name'] == 'Coldplay')]['score_scale'],
# ----> 5           c='b', label='data', s=40)
#       6
#       7 #ax.scatter(x=df[(df['venue.timezone'] ==  'America/Chicago') &
#
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3635             edgecolors = 'face'
#    3636
# -> 3637         offsets = np.dstack((x, y))
#    3638
#    3639         collection = mcoll.PathCollection(
#
# //anaconda/lib/python2.7/site-packages/numpy/lib/shape_base.pyc in dstack(tup)
#     366
#     367     """
# ...

# %%
df.columns
# Out:
# Index([u'announce_date', u'artist_name', u'created_at', u'date_tbd',
#        u'datetime_local', u'datetime_tbd', u'datetime_utc',
#        u'general_admission', u'id', u'links', u'performers', u'score',
#        u'short_title', u'stats.average_price', u'stats.highest_price',
#        u'stats.listing_count', u'stats.lowest_price',
#        u'stats.lowest_price_good_deals', u'taxonomies', u'time_tbd', u'title',
#        u'type', u'url', u'venue.address', u'venue.city', u'venue.country',
#        u'venue.display_location', u'venue.extended_address', u'venue.id',
#        u'venue.links', u'venue.location.lat', u'venue.location.lon',
#        u'venue.name', u'venue.postal_code', u'venue.score', u'venue.slug',
#        u'venue.state', u'venue.timezone', u'venue.url', u'visible_until_utc',
#        u'concert_score', u'stats.highest_price_stdsc', u'score_scale'],
#       dtype='object')
